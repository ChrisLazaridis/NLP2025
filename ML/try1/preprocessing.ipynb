# %% [markdown]
# # Workflow
# ## 1. Preprocessing & Vocabulary Construction
# #### 1.1 Rule-Based Tokenization
# Implement a deterministic tokenizer that splits on whitespace, punctuation, and language-specific clitics, following best practices in NLP pipeline design
# #### 1.2 POS Tagging
# Use nltk to reliably POS tag the sentences of the text
# #### 1.3 Finite-State Lemmatization
# Construct a two-level morphological analyzer based on Koskenniemi’s framework, encoding suffix-stripping and morphophonological alternation rules as finite-state transducers to derive lemmas
# #### 1.4 Vocabulary Lookup Table
# Aggregate unique lemma–POS pairs into a lexicon, recording token frequencies and contextual usage to constrain later transformations.
# ## 2. Sentence Generation from Vocabulary
# #### 2.1 Template-Driven Sentence Synthesis
# - Define a diverse set of syntactically richer templates spanning multiple clause types (e.g., simple transitive, passive, ditransitive, relative clauses, subordinations).
# - Represent each template as a shallow dependency skeleton with labeled slots
# - Sample lemmas from the vocabulary lookup table using frequency-weighted or stratified selection to fill each slot, and enforce feature unification (gender, number, person) to guarantee agreement.
# - Linearize filled skeletons into surface strings via deterministic ordering rules, then score and rank candidates using a pretrained language model or n‑gram extractor to retain the top‑K most fluent instantiations per template.
# - Optionally apply semantic compatibility checks—e.g., distributional similarity thresholds or selectional preference models—to filter out semantically anomalous slot combinations.
#
# #### 2.2 Constraint Enforcement
# Apply simple agreement and subcategorization checks—using POS sequences and verb valency from the lookup table—to filter out invalid or ungrammatical const
# ## 3. Seed Sentence Curation
# #### 3.1 Lexical Clarity Selection
# Filter generated sentences to retain only those where each lemma occurs with a single dominant sense in context, as characterized in Navigli’s survey.
# #### 3.2 Syntactic Clarity Selection
# Ensure prepositional-phrase attachments are unambiguous by selecting sentences where Hindle & Rooth’s likelihood-ratio criterion for PP attachment strongly favors one parse (e.g., λ ≫ 0).
# ## 4. Ambiguity Transformation Rules
# #### 4.1 Lexical Ambiguity (Hononym Substitution)
# Replace unambiguous lemmas with contextually plausible homonyms drawn from the corpus lexicon, ensuring multiple sense readings without changing surrounding syntax
# #### 4.2 Structural Ambiguity (PP Attachment Flip)
# For sentences containing a PP, swap its attachment site—reattach a PP from its original head (noun vs. verb) to the alternate—to create two distinct parses
# #### 4.3 Referential Ambiguity (Pronoun Insertion)
# Insert or replace noun phrases with pronouns in Winograd-style schemas, introducing antecedent ambiguity that requires world knowledge or context to resolve
# ## 5. Optional Model-Based Refinement
# Use a reversed syntactically controlled paraphrase network (trained as in Iyyer et al. 2018) to regenerate each ambiguous sentence, conditioning on its original unambiguous parse template to improve fluency and adherence to the target ambiguity pattern

# %% [markdown]
# # IMPORTS

# %%
import re
import math
import spacy
from collections import defaultdict, Counter
from typing import List, Tuple, Dict
import nltk
import pandas as pd
import random
from nltk.corpus import wordnet as wn, brown
nltk.download('wordnet', quiet=True)
nltk.download('brown', quiet=True)
nltk.download('punkt', quiet=True)
nltk.download('averaged_perceptron_tagger', quiet=True)
nlp = spacy.load("en_core_web_sm")
import itertools
from itertools import product
import csv
from tqdm.notebook import tqdm

# %% [markdown]
# ## Texts we are going to be working with
# #### Text 1:
#
# Today is our dragon boat festival, in our Chinese culture, to celebrate it with all safe and great in
# our lives. Hope you too, to enjoy it as my deepest wishes.
# Thank your message to show our words to  the doctor, as his next contract checking, to all of us.
# I got this message to see the approved message. In fact, I have received the message from  the
# professor, to show me, this, a couple of days ago.  I am very appreciated  the full support of the
# professor, for our Springer proceedings publication
# #### Text 2:
# During our final discuss, I told him about the new submission — the one we were waiting since
# last autumn, but the updates was confusing as it not included the full feedback from reviewer or
# maybe editor?
#  Anyway, I believe the team, although bit delay and less communication at recent days, they really
# tried best for paper and cooperation. We should be grateful, I mean all of us, for the acceptance
# and efforts until the Springer link came finally last week, I think.
#  Also, kindly remind me please, if the doctor still plan for the acknowledgments section edit before
# he sending again. Because I didn’t see that part final yet, or maybe I missed, I apologize if so.
#  Overall, let us make sure all are safe and celebrate the outcome with strong coffee and future
# targets

# %%
text1 = (
    "Today is our dragon boat festival, in our Chinese culture, to celebrate it "
    "with all safe and great in our lives. Hope you too, to enjoy it as my "
    "deepest wishes. Thank your message to show our words to the doctor, as his "
    "next contract checking, to all of us. I got this message to see the approved "
    "message. In fact, I have received the message from the professor, to show me, "
    "this, a couple of days ago. I am very appreciated the full support of the "
    "professor, for our Springer proceedings publication"
)
text2 = (
    "During our final discuss, I told him about the new submission — the one we were "
    "waiting since last autumn, but the updates was confusing as it not included the "
    "full feedback from reviewer or maybe editor? Anyway, I believe the team, although "
    "bit delay and less communication at recent days, they really tried best for paper "
    "and cooperation. We should be grateful, I mean all of us, for the acceptance and "
    "efforts until the Springer link came finally last week, I think. Also, kindly remind "
    "me please, if the doctor still plan for the acknowledgments section edit before he "
    "sending again. Because I didn’t see that part final yet, or maybe I missed, I apologize "
    "if so. Overall, let us make sure all are safe and celebrate the outcome with strong "
    "coffee and future targets"
)

# %% [markdown]
# # 1. Preprocessing & Vocabulary Construction

# %% [markdown]
# ## 1.1 Rule Based Tokenizer

# %%
# Cell 3
def tokenize(text: str) -> List[str]:
    """
    Tokenizes the input text into a list of tokens.
    """
    text = text.replace('\n', ' ')
    pattern = r"""(
        (?:[A-Za-z]+(?:'t|'re|'ve|'ll|'d|'s|'m))  # Words with clitics
        |[A-Za-z]+                                # Words
        |\d+(?:\.\d+)?                            # Numbers, including decimals
        |[.,!?;:"()\[\]\/\\]                     # Punctuation
    )"""
    return re.findall(pattern, text, flags=re.VERBOSE)

def tokenize_paragraph(paragraph: str) -> List[List[str]]:
    """
    Tokenizes a paragraph into sentences then words.
    """
    sentences = re.split(r'(?<=[\.!?])\s+', paragraph)
    return [tokenize(s) for s in sentences if s]

# %% [markdown]
# ### This tokenizer:
# - **splits on whitespaces** (after normalizing new lines)
# - **Handles punctuation** as seperate tokens
# - **Isolates English Clitics** (e.g. ’t, ’re, ’ve, ’ll, ’d, ’s, ’m) from their hosts
#
# The function uses a single regular expression so that the behavior is transparent and easy to adapt (for example, to add or remove clitics or punctuation marks).

# %% [markdown]
# ## 1.2 POS Tagging
# #### nltk's `average perceptron tagger` can find the following tags which are plenty for our two paragrapgs
# | Tag   | Meaning                                         |
# |-------|-------------------------------------------------|
# | CC    | Coordinating conjunction                        |
# | CD    | Cardinal number                                 |
# | DT    | Determiner                                      |
# | EX    | Existential “there”                             |
# | FW    | Foreign word                                    |
# | IN    | Preposition or subordinating conjunction        |
# | JJ    | Adjective                                       |
# | JJR   | Adjective, comparative                          |
# | JJS   | Adjective, superlative                          |
# | LS    | List item marker                                |
# | MD    | Modal auxiliary                                 |
# | NN    | Noun, singular or mass                          |
# | NNS   | Noun, plural                                    |
# | NNP   | Proper noun, singular                           |
# | NNPS  | Proper noun, plural                             |
# | PDT   | Predeterminer                                   |
# | POS   | Possessive ending                               |
# | PRP   | Personal pronoun                                |
# | PRP$  | Possessive pronoun                              |
# | RB    | Adverb                                          |
# | RBR   | Adverb, comparative                             |
# | RBS   | Adverb, superlative                             |
# | RP    | Particle                                        |
# | TO    | “to” (as preposition or infinitive marker)      |
# | UH    | Interjection                                    |
# | VB    | Verb, base form                                 |
# | VBD   | Verb, past tense                                |
# | VBG   | Verb, gerund or present participle              |
# | VBN   | Verb, past participle                           |
# | VBP   | Verb, non-3rd-person singular present            |
# | VBZ   | Verb, 3rd-person singular present               |
# | .     | Sentence-final punctuation                      |
# | ,     | Comma                                           |

# %%
texts = [text1, text2]
records = []

for text_id, text in enumerate(texts, start=1):
    for sentence_id, tokens in enumerate(tokenize_paragraph(text), start=1):
        tagged = nltk.pos_tag(tokens)
        for token, pos in tagged:
            records.append({
                'text_id': text_id,
                'sentence_id': sentence_id,
                'token': token,
                'pos': pos
            })

pos_tags_df = pd.DataFrame(records)
pos_tags_df.to_csv('data/pos_tags.csv', index=False)

# %% [markdown]
# ## 1.3 Finite-State Lemmatization

# %% [markdown]
# We implement a **two-level morphological model** in a simplified form:
#
# 1. **Suffix rules** (longest first):
#    - `-ies` → `-y` (e.g. *studies* → *study*)
#    - `-ves` → `-f` (e.g. *leaves* → *leaf*)
#    - `-es` → `∅` (e.g. *boxes* → *box*)
#    - `-ing` → `∅` (e.g. *running* → *run*)
#    - `-ed` → `∅` (e.g. *jumped* → *jump*)
#    - `-s` → `∅`, except when the word ends in `-ss` (e.g. *glass* remains `glass`)
# 2. **Context-free application**, akin to Koskenniemi’s two-level rules, but here executed sequentially in code rather than via a compiled FST[^1][^11].
#
# This cascade covers the most common English inflectional patterns and approximates a finite-state transducer for lemmatization[^2][^5].

# %%
def lemmatize_word(word: str) -> str:
    """
    Lemmatizes a word based on simple English rules.
    """
    if word.endswith("ies") and len(word) > 4:
        return word[:-3] + "y"
    if word.endswith("ves") and len(word) > 4:
        return word[:-3] + "f"
    if word.endswith("es") and len(word) > 3:
        return word[:-2]
    if word.endswith("ing") and len(word) > 4:
        return word[:-3]
    if word.endswith("ed") and len(word) > 3:
        return word[:-2]
    if word.endswith("s") and not word.endswith("ss") and len(word) > 3:
        return word[:-1]
    return word

# %%
data = []
texts = [text1, text2]

for text_id, text in enumerate(texts, start=1):
    for sentence_id, tokens in enumerate(tokenize_paragraph(text), start=1):
        for token in tokens:
            lemma = lemmatize_word(token.lower())
            data.append({
                'text_id': text_id,
                'sentence_id': sentence_id,
                'token': token,
                'lemma': lemma
            })

lemmatized_df = pd.DataFrame(data)
lemmatized_df.to_csv('data/lemmatized_tokens.csv', index=False)

# %% [markdown]
# ## 1.4 Vocabulary Lookup Table
# 1. **Reading your CSVs**
#    Loads the two pre-existing DataFrames: one with POS tags and one with lemmas.
# 2. **Renaming**
#    Aligns the column names (`Original_Token` vs. `token`) so that pandas can match rows correctly.
# 3. **Merging**
#    Performs a left-join on `TextID` and the surface token, ensuring every POS-tagged token gets its lemma attached.
# 4. **Aggregation**
#    - **`frequency`**: how many times each `(lemma, POS)` pair occurs.
#    - **`examples`**: up to three distinct original tokens showing that lemma+POS in context.
# 5. **Saving**
#    Exports the final lexicon to `vocab_lookup.csv`, ready for downstream use in your lexicon-driven transformations.

# %%
# 1. Load CSVs
pos_tags_df      = pd.read_csv('pos_tags.csv')
lemmatized_df    = pd.read_csv('lemmatized_tokens.csv')

# 2. Merge on text_id, sentence_id, token
merged_df = pd.merge(
    pos_tags_df,
    lemmatized_df,
    on=['text_id', 'sentence_id', 'token'],
    how='left'
)

# 3. Build vocabulary lookup
vocab_lookup_df = (
    merged_df
      .groupby(['lemma', 'pos'], as_index=False)
      .agg(
           tokens    = ('token', lambda toks: list(pd.unique(toks))),
          frequency=('lemma', 'size'),
          examples=('token', lambda toks: list(pd.unique(toks)[:3]))
      )
)
vocab_lookup_df = vocab_lookup_df[
    ['tokens', 'lemma', 'pos', 'frequency', 'examples']
]
# 4. Save to CSV
vocab_lookup_df.to_csv('data/vocab_lookup.csv', index=False)

# %% [markdown]
# # 2. Sentence Generation from Vocabulary

# %% [markdown]
# Generating syntactically correct and semantically clear sentences can be achieved by using template-based generation with a controlled vocabulary of part-of-speech (POS) tags. In this approach, we define sentence structures as sequences of POS tags (e.g., Determiner + Noun + Verb + Object) and then populate these structures with actual words that exemplify each POS category. This method is a simple yet powerful form of Natural Language Generation (NLG) that avoids randomness: given the same templates and vocabulary, it will always produce the same sentences (i.e., it is fully deterministic).Such template-based generation is ideal for tasks that require control and consistency over language output, significantly reducing ambiguity and ensuring grammatical correctness. The use of POS tag templates also aligns with the concept of syntactic templates in the literature, which are sequences of POS tags representing sentence patterns.
#
# ## Approach and Template Design
# 1. **Corpus Selection**
#    - Load sentences from the Brown corpus’s “government” and “learned” categories to approximate a formal/letter register.
#
# 2. **Custom Parsing**
#    - Tokenize and POS-tag each sentence using NLTK’s built-in tools, rather than a heavyweight parser.
#
# 3. **Tag Filtering**
#    - Define exactly which Penn Treebank tags your generator knows (e.g. `DT`, `NN`, `PRP$`, etc.).
#    - Discard any sentence whose POS sequence contains tags outside this whitelist.
#
# 4. **Length Constraint**
#    - Only consider sentences between 10 and 18 tokens long, so that templates produce sufficiently rich, paragraph-like seed sentences.
#
# 5. **Template Extraction**
#    - Count how often each “clean” POS sequence (template) occurs in the filtered corpus.
#    - Select the top 50 most frequent sequences.
#
# 6. **Template Formatting**
#    - Build a dictionary where each key is the space-joined tag string (e.g. `"PRP VBD DT NN IN DT JJ NN"`) and each value is the corresponding list of tags.
#    - This map plugs directly into your existing generator loop (`generate_sentences(pattern, vocab_map)`).
#
#
# ---
# ## Pipeline Implementation in Python
# - **Vocabulary Construction:** We define a dictionary mapping each POS tag to a list of example words (lemmas) for that tag. This can be derived from the provided lookup CSV (for reproducibility, we show a hard-coded small selection of words per tag in this example). In a real scenario, one could parse the full lookup table to build this dictionary. Each list is kept in a fixed order so that iteration is deterministic. (We also ensure the words are in the correct case for usage; e.g., pronoun “I” is capitalized because it must always appear as “I”.)
# - **Template Definitions:** We define templates as patterns of POS tags. For convenience, each template is represented as a list of tags (or a string of tags). We also store an example template pattern description for clarity. These templates correspond to structures, for instance, ["DT","NN","VBZ","DT","NN"] represents Det + Noun + Verb + Det + Noun.
# - **Sentence Generation Function:** A function generate_sentences(pattern) uses the vocabulary to produce all possible sentences for a given tag pattern. It does so by taking the Cartesian product of the word lists for each tag in the pattern (ensuring every combination of choices is covered)
# researchgate.net
# . For each combination, it joins the words into a sentence, capitalizes the first letter, and adds a period at the end. (Capitalization and punctuation are added as a post-processing step to make the output look like proper English sentences.) Because we iterate in a consistent order (e.g., the order of tags in the template and the order of words in each tag’s list never changes), the generation is deterministic in both content and order of sentences.

# %%
raw_sents = [' '.join(sent) for sent in brown.sents(categories=['government', 'learned'])]
# — 2) Homemade parser: tokenize + POS-tag —
def parse_sent(text):
    toks = nltk.word_tokenize(text)
    tags = [tag for (_, tag) in nltk.pos_tag(toks)]
    return toks, tags

# — 3) Define your allowed Penn Treebank tags —
vocab_lookup = pd.read_csv('data/vocab_lookup.csv')
allowed_tags = set(vocab_lookup['pos'].dropna().unique())
allowed_tags |= {'.', ','}

# — 4) Count templates of length 10–18, discarding any containing an unknown tag —
tpl_counts = Counter()
for sent in raw_sents:
    toks, tags = parse_sent(sent)
    L = len(toks)
    if 12 <= L <= 20 and set(tags).issubset(allowed_tags):
        tpl = tuple(tags)
        tpl_counts[tpl] += 1

# — 5) Take the top 50 most frequent “clean” templates —
top_templates = [tpl for tpl, _ in tpl_counts.most_common(50)]

# — 6) Build the dict you’ll feed into your generator —
templates = {
    " ".join(tpl): list(tpl)
    for tpl in top_templates
}

# %% [markdown]
# ### Vocabulary Coverage & Enrichment
#
# We now split our lookup vocabulary into **primary** and **secondary** pools, then generate two batches of sentences:
#
# 1. **Primary (Coverage) Pass**
#    - **Primary** = all lemmas from `vocab_lookup.csv`.
#    - For each primary lemma _ℓ_ of POS tag _t_:
#      1. Pick a random template that contains tag _t_.
#      2. **Force** ℓ into its slot.
#      3. Fill remaining slots with a mix of primary + secondary lemmas.
#    - **Sentences generated**:
#      $$
#        \sum_{t}\bigl|\text{primary}_t\bigr|
#        \;=\;154
#      $$
#
# 2. **Secondary (Enrichment) Pass**
#    - **Secondary** = all other WordNet lemmas (minus primaries), pruned to max 20 per tag.
#    - For each of the **50** templates:
#      - Fill **all** slots with secondary lemmas only.
#      - Repeat **500** times per template.
#    - **Sentences generated**:
#      $$
#        50 \times 500 \;=\;25{,}000
#      $$
#
# ---
#
# ### Total Sentences
#
# $$
# 154\;(\text{coverage})\;+\;25{,}000\;(\text{enrichment})
# \;=\;25{,}154\quad\text{sentences.}
# $$

# %%
# --- A) Build primary vs secondary vocab ---

# --- 1) Load your lookup table ⇒ primary_vocab + gather CSV tags ---
vocab_lookup = pd.read_csv('data/vocab_lookup.csv')  # cols: pos, lemma
lookup_map = defaultdict(list)
for _, row in vocab_lookup.iterrows():
    tag, lemma = row['pos'], row['lemma']
    if pd.notna(tag) and pd.notna(lemma):
        lookup_map[tag].append(lemma)
primary_vocab = { tag: sorted(lookup_map[tag]) for tag in lookup_map }
all_tags      = set(primary_vocab.keys())

# --- 2) Full PTB→WordNet mapping for supported tags ---
_full_ptb2wn = {
    'NN': wn.NOUN, 'NNS': wn.NOUN, 'NNP': wn.NOUN, 'NNPS': wn.NOUN,
    'VB': wn.VERB, 'VBD': wn.VERB, 'VBG': wn.VERB, 'VBN': wn.VERB,
    'VBP': wn.VERB, 'VBZ': wn.VERB,
    'JJ': wn.ADJ, 'JJR': wn.ADJ, 'JJS': wn.ADJ,
    'RB': wn.ADV, 'RBR': wn.ADV, 'RBS': wn.ADV
}
ptb2wn = { tag: wn_pos for tag, wn_pos in _full_ptb2wn.items() if tag in all_tags }
brown_map = defaultdict(set)
for sent in brown.sents(categories=['government','learned']):
    toks = nltk.word_tokenize(' '.join(sent))
    for word, tag in nltk.pos_tag(toks):
        if tag in all_tags:
            brown_map[tag].add(word.lower())

# --- 4) Build source_vocab: primary from CSV + secondary from WordNet or Brown ---
source_vocab = {}
for tag in all_tags:
    prim_list = sorted(set(primary_vocab[tag]))
    if tag in ptb2wn:
        all_lemmas = set(wn.all_lemma_names(pos=ptb2wn[tag]))
        prim_set   = set(prim_list) & all_lemmas
        # use WordNet lemmas minus your primaries
        sec_list   = sorted(all_lemmas - prim_set)
    else:
        # use Brown tokens minus your primaries
        sec_list   = sorted(brown_map[tag] - set(prim_list))
    source_vocab[tag] = {
        'primary': sorted(prim_set if tag in ptb2wn else prim_list),
        'secondary': sec_list
    }

# --- 5) Prune secondary lists so they don’t explode ---
def prune_secondary(vmap, max_per_slot=20):
    pruned = {}
    for tag, pools in vmap.items():
        sec = pools['secondary']
        pruned[tag] = {
            'primary': pools['primary'],
            'secondary': (random.sample(sec, max_per_slot)
                          if len(sec) > max_per_slot else sec.copy())
        }
    return pruned

vocab = prune_secondary(source_vocab, max_per_slot=20)
# save to CSV for later use
vocab_df = pd.DataFrame.from_dict(vocab, orient='index')
vocab_df.to_csv('vocab.csv', index=False)
# --- B) Two‐phase sentence generation ---

# Helper to fill a pattern once, forcing a specific word in one slot
def fill_template(pattern, forced_tag=None, forced_word=None):
    slots = []
    for tag in pattern:
        if tag == forced_tag:
            slots.append([forced_word])
        else:
            # mix primary & secondary for the other slots
            pool = vocab[tag]['secondary'] + vocab[tag]['primary']
            slots.append(pool)
    choice = [random.choice(pool) for pool in slots]
    return " ".join(choice).capitalize() + "."

# figure out which tags actually occur in your templates
template_tags = {
    tag
    for pattern in templates.values()
    for tag in pattern
}

# 1) COVERAGE: one sentence per (tag, primary_lemma),
#    but only for tags that appear in at least one template
coverage = []
for tag, pools in vocab.items():
    if tag not in template_tags:
        continue            # skip any tag not in your templates
    for lemma in pools['primary']:
        # now we know there is at least one template that contains this tag
        candidates = [tpl for tpl,p in templates.items() if tag in p]
        tpl        = random.choice(candidates)
        pattern    = templates[tpl]
        sent       = fill_template(pattern, forced_tag=tag, forced_word=lemma)
        coverage.append({'sentence': sent, 'pattern': tpl})

# 2) ENRICHMENT: sample many more with both secondary & primary words
enriched = []
SAMPLES_PER_TEMPLATE = 500
for tpl, pattern in templates.items():
    for _ in range(SAMPLES_PER_TEMPLATE):
        # fill_template(pattern) mixes secondary + primary for every slot
        s = fill_template(pattern)
        enriched.append({'sentence': s, 'pattern': tpl})

# 3) Combine and save
all_sents = coverage + enriched
df = pd.DataFrame(all_sents)
df.to_csv('data/generated_sentences.csv', index=False)

# %% [markdown]
# # 3. Seed Sentence Curation

# %% [markdown]
# # 3.1 Lexical Clarity Filtering
#
# We require each lemma in a sentence to have one sense (POS) that accounts for ≥ 90 % of its corpus usage:
#
# $$
# p_{\max}(L)
# = \frac{\max_{s} f(L,s)}{\sum_{s} f(L,s)}
# \;\ge\; \theta\;(=0.9).
# $$

# %%
# === Parameters ===
THETA_LEX  = 0.9
PP_CUTOFF  = 0.9

# Load generated sentences
gen_df = pd.read_csv('generated_sentences.csv')
gen_df['sentence_id'] = gen_df.index

# Load vocab lookup
vocab_df = pd.read_csv('vocab_lookup.csv')

# Build lemma→POS frequency map
lemma_pos = (
    vocab_df
      .groupby(['lemma', 'pos'])['frequency']
      .sum()
      .unstack(fill_value=0)
)
lemma_pos['total'] = lemma_pos.sum(axis=1)
lemma_pos['p_max'] = lemma_pos.max(axis=1) / lemma_pos['total']

# Ambiguous lemmas
ambiguous_lemmas = set(lemma_pos[lemma_pos['p_max'] < THETA_LEX].index)

# Simple tokenizer
tok_re = re.compile(r'\b\w+\b')
def tokenize_sentence(text: str) -> List[str]:
    return tok_re.findall(text.lower())

def is_lexically_clear(sentence: str) -> bool:
    toks = tokenize_sentence(sentence)
    return not any(tok in ambiguous_lemmas for tok in toks)

gen_df['lex_clear'] = gen_df['sentence'].apply(is_lexically_clear)

# %% [markdown]
# # 3.2 Syntactic Clarity Filtering (PP Attachment)
#
# For each PP (`IN` + noun) in the **corpus**, we estimate
#
# $$
# P(p \mid \text{noun}=N)
# \approx \frac{C(N,p)+1}{C(N)+|P|},
# \quad
# P(p \mid \text{verb}=V)
# \approx \frac{C(V,p)+1}{C(V)+|P|}
# $$
#
# where we’ve added +1 (Laplace) smoothing and `|P|` = number of distinct prepositions.
# Then, in each candidate sentence, if a PP follows a noun *and* a verb, we keep it **only** if
#
# ```text
# max(P(p|N), P(p|V)) ≥ 0.9

# %%
# Load POS tags and lemmatized tokens
pos_df   = pd.read_csv('pos_tags.csv')
lemma_df = pd.read_csv('lemmatized_tokens.csv')

# Merge on text_id, sentence_id, token
cf_df = pos_df.merge(
    lemma_df,
    how='inner',
    on=['text_id', 'sentence_id', 'token']
)

# Prepositions set
PREPS = set(cf_df[cf_df['pos'] == 'IN']['token'].str.lower())
P     = len(PREPS)

# Counters
C_np = defaultdict(int)
C_vp = defaultdict(int)
C_n  = Counter()
C_v  = Counter()

# Populate counts
for sid, group in cf_df.groupby('sentence_id'):
    rows = list(group[['token','pos','lemma']].itertuples(index=False, name=None))
    for tok, ptag, lem in rows:
        if ptag.startswith('NN'):
            C_n[lem] += 1
        elif ptag.startswith('VB'):
            C_v[lem] += 1
    for i, (tok, ptag, lem) in enumerate(rows):
        prep = tok.lower()
        if ptag == 'IN' and prep in PREPS and i > 0:
            prev_tok, prev_pos, prev_lem = rows[i-1]
            if prev_pos.startswith('NN'):
                C_np[(prev_lem, prep)] += 1
            for j in range(i-1, -1, -1):
                if rows[j][1].startswith('VB'):
                    C_vp[(rows[j][2], prep)] += 1
                    break

# Smoothed probability
def P_given(counts, totals, key):
    return (counts.get(key, 0) + 1) / (totals[key[0]] + P)

def is_syntactically_clear(sid: int) -> bool:
    rows = list(
        cf_df[cf_df['sentence_id'] == sid][['token','pos','lemma']]
        .itertuples(index=False, name=None)
    )
    for i, (tok, ptag, lem) in enumerate(rows):
        prep = tok.lower()
        if ptag == 'IN' and prep in PREPS and i > 0:
            prev_tok, prev_pos, prev_lem = rows[i-1]
            pn = (P_given(C_np, C_n, (prev_lem, prep))
                  if prev_pos.startswith('NN') else 0.0)
            verb_lem = next(
                (r_lem for _, r_pos, r_lem in reversed(rows[:i])
                 if r_pos.startswith('VB')),
                None
            )
            pv = (P_given(C_vp, C_v, (verb_lem, prep)) if verb_lem else 0.0)
            if max(pn, pv) < PP_CUTOFF:
                return False
    return True

gen_df['syn_clear'] = gen_df['sentence_id'].apply(is_syntactically_clear)

# Final seed sentences
curated = gen_df.loc[gen_df['lex_clear'] & gen_df['syn_clear'], 'sentence'].tolist()
print("## Curated Seed Sentences\n")
for s in curated:
    print(f"- {s}")

# Save to CSV
curated_df = pd.DataFrame(curated, columns=['sentence'])
curated_df.to_csv('data/seed_sentences.csv', index=False)
# Out:
# ## Curated Seed Sentences
#
# - He frap and chuck neither next delay , link along lacustrine junky , and recent frostian submission lighting_fixture ..
# - Himself chuck again thi outcome at top poems thi word though us think invite !.
# - Timber , hareem foreign_terrorist_organization white_fritillary , support junky , eloquent pageantry mean proceeding to fall_away ..
# - Be hypercalcemia standardise this chinese communication out another lacustrine editor today black_person at teacher professor berlage ?.
# - One light-heartedly fagot send virus an coral_bean dur rancidness to step_on crotal though themselves put_on_the_line programme ..
# - Themselves still lace wait overflow half bit because rancidness to let white_fritillary out one mean tail ?.
# - Thi silene_caroliniana muck_about to half anorthic & part , but me partially desensitize one plan !.
# - Overleaf illiberally awaken acceptance sunbathe na see acceptance gravity_wave neither acceptance ..
# - Provide a hasher anorthic autumn like theorem mastigoproctus along thi autumn theirs rediscover partition_off last full annona ?.
# - Dur any great bit divide this bit lace legitimate , no rampant bit john_drew ca show sabotage !.
# - I fort but playact any inexplicit boat , boat under natty proceeding , and new safe boat effort !.
# - Check rancidness take_a_breath those bawl_out goddamn at an calliphora_vicina nor annona & premedical provencal check junky !.
# - They deaminate again bawl_out coffee na make no strong coffee out theorem anorthic coffee ?.
# - 1908 premedical white_fritillary keep_track lighting_fixture , surplus finally next last communication ..
# - Plow contract , another hope junky grateful word because contract since undiscipline minus contract contract briefly theorem contract ..
# - Trapezoidal , you can fall_away cooperation overflow rampant gravity_wave outmatch despite both cooperation about effusive crotal divide any cooperation ..
# - Couple word apologize the sabotage illiberally provide each timber & appendage plus contorted rampant couple acknowledgment !.
# - Every strong culture culture , berlage poems ecchymosis , impregnate that culture if teacher assortment john_drew timber under 7.2 !.
# - Last ii outmatch act_involuntarily partition_off na show grateful delay panicum_capillare despite delay wish ?.
# - Doctor virus doctor wish awaken rat illiberally to each doctor st._john_chrysostom ..
# - Gravity_wave give_the_gate vandalise basely under a rabbit-sized dragon background a dragon in dragon !.
# - Editor until editor effort awaken bemoan perkily to the editor st._john_chrysostom ?.
# - We ago jag localise although some fact poems word na let ii about itself apologize rat !.
# - Ii programme like thi murrumbidgee_river see swipe worth an feedback provide feedback overflow theorem feedback ?.
# - Herself should , goddamn , rough-hew bemoan to festival festival junky ?.
# - Themselves pull_someone's_leg too despite hasher link despite that undiscipline until ourselves et unconstitutionally march_on beneath my link ..
# - Message though premedical target provide message deaminate strong must buy_back call_down ..
# - Full , they can seaplane outcome beneath overall appendage apprentice briefly half outcome dur effusive wish overflow teacher outcome ..
# - Paper appendage believe acrobatic as mastigoproctus cheeky acknowledgment to let calorie-free recent paper rancidness like frostian paper target ..
# - Her judge but playact any last part , part overflow lank cross-country_riding , but next great part appendage ..
# - Poems plan either settle 1908 plan because this assortment john_drew , john_drew nor grass_tree_family grass_tree_family ?.
# - White_fritillary dowse astride every calliphora_vicina believe rat with another professor if professor provide thee professor !.
# - Myself tenderise still optimum my publication at neither proceeding along he et perkily rule_in plow her publication ..
# - Reviewer poems dominated arc_cosine background reviewer keep_track eloquent shall seaplane sunbathe !.
# - Next section , half murrumbidgee_river junky holophytic junky despite section divide lighting_fixture both section section from theorem section !.
# - Neither submission provide trapezoidal third-degree_burn background submission of antiparticle briefly submission lighting_fixture penetratingly though submission panicum_capillare !.
# - They ought rule_in sabotage since white_fritillary if sure target worth support gain severally recent arc_cosine as support rabbit-sized undiscipline !.
# - Team pageantry despite checkered_daffodil inexplicit word encrimson grateful na remind frostian dominated team crotal poems eloquent team lighting_fixture ..
# - Despite an his recent today as some hope next these today he have film strong eloquent pageantry !.
# - Lighting_fixture whisk_away programme very with a safe week at thee week of week ..
# - Some tollkeeper jag kindly programme support outcome poems acknowledgment although first_sacker acknowledgment ?.
# - An day waver professor or flop along day discolor grateful buy_at na day ?.
# - So municipally judge hareem invite to recreate plan effort and cooperation !.
# - Every proceeding lurch genus_limnocryptes or communication as proceeding give_the_gate effusive send to proceeding ..
# - Tollkeeper judge buckram illiberally briefly target plow impracticableness editor et tollkeeper couple ..
# - 'em bog too plow her delay from no wish like she yet too standardise next their outcome !.
# - Neither submission despite word overflow any boat that genus_steatornis word shall illiberally , despite professor , show final !.
# - Out hurler's_disease , theorem family_lecanoraceae crotal rampant lighting_fixture background plan as giovanni_boccaccio & editor arthropod background each contract ?.
# - Contract frap call_down illiberally about junky about silene_caroliniana editor nor foreign_terrorist_organization boat ?.
# - 7074 chinese ii bias annona , yet light-heartedly although acrobatic paper ?.
# - Her would celebrate tail as effort as natty word as cuban_spinach bias very next antiparticle as support provencal antiparticle ..
# - A week chuck tail na ordinate surplus celebrate holophytic submission at that cuban_spinach to march_on bawl_out ?.
# - Next , you must seaplane maidu because safe cordwood shoot_for because half festival because grateful cordwood because any tollkeeper !.
# - Each white_fritillary get_laid arthropod or sales_finance_company before antiparticle bias holophytic send to panicum_capillare ?.
# - Them breathe_out edgewise both cooperation dur re-incorporate dur some giovanni_boccaccio dur she discolor film ..
# - For unproblematic pageantry herself can make either recreate your culture na day for_the_asking edgewise inexplicit na fall_away grateful st._john_chrysostom ..
# - Link from feedback wish disinvest rat basely na thee cuban_spinach word ?.
# - If springer roof_rack anyway redline timber , her part cuban_spinach , teacher us edgewise bog assortment ?.
# - Theorem acceptance slake in half sure 1,418,000 crotal in some delay programme in fort too in safe frostian third-degree_burn !.
# - You fort sunbathe of these rabbit-sized foreign_terrorist_organization no great trapezoidal reviewer of inexplicit impracticableness ?.
# - It 'll consolidate bawl_out since cross-country_riding since calorie-free third-degree_burn since week needle hesitatingly final giovanni_boccaccio since reviewer frostian gravity_wave !.
# - Chinese that some ii mean disturbingly safe that theirs may be dowse so that him !.
# - Angioplasty until eloquent word until hareem see provencal must make invite ..
# - You might wrick slake with gravity_wave with new effort with link remain not lacustrine wish with festival future st._john_chrysostom !.
# - It miss goddamn until their plan divide no proceeding for it yet too tape that his support !.
# - Me would , finally , remilitarise film to tollkeeper sales_finance_company pageantry ?.
# - Chinese pageantry put_on_the_line yet needle acknowledgment for gravity_wave though team plan ..
# - For all final plan about teacher paper awaken spreadeagle , another final coffee assortment will wrick buckram ..
# - Half festival for full gravity_wave overflow culture though impreciseness of coral_bean st._john_chrysostom for_the_asking under professor cordwood ..
# - She apologize again bemoan editor na show either future couple background both future genus_steatornis !.
# - Herself hesitatingly redline under buy_at thee grateful festival of photosensitize about herself cut_out of an skinny briefly grass_tree_family ?.
# - A rip_van_winkle bawl_out until half great 2.8 st._john_chrysostom optimum teacher week programme about frap for_the_asking as great great third-degree_burn ..
# - Thi tollkeeper jag na another last minus week , plus broken picturesquely pierce 1.25 tojo ..
# - New maidu word but her new effort apprentice new though of the check before murrumbidgee_river pageantry ..
# - Reviewer wish background roof_rack next cordwood remain next to standardise next next coral_bean panicum_capillare virus next flop annona !.
# - A overall doctor submission , roof_rack poems berlage , lace although rip_van_winkle of half john_drew ecchymosis mastigoproctus from 613 !.
# - Recent out some junky needle perkily recent from 'em need remind programme fleetly beneath himself !.
# - Safe wish put_on_the_line hit_home programme to show safe editor target briefly rip_van_winkle antiparticle ?.
# - Every cooperation like strong annona next acceptance because cordwood under culture gravity_wave again poems contract cross-country_riding ..
# - Sure lighting_fixture whisk_away but put_on_the_line white_fritillary before rancidness like support professor ..
# - Those hurler's_disease settle to an dominated neither dragon , or he too fagot 80 culture ?.
# - Basely him rope_up spreadeagle some first_sacker until festival unconstitutionally though teacher arc_cosine from each safe white_fritillary ..
# - I light-heartedly awaken honor beneath half tojo if ii na ordinate annona because i discolor vandalise ?.
# - Each section fagot to either rabbit-sized nor tollkeeper , et it goddamn disinvest 1,418,000 festival ..
# - Me pierce call_down since teacher assortment fact like a eloquent proceeding astride no impracticableness !.
# - That future effort they should march_on plus wrick her plan na panicum_capillare also very sure na rough-hew great giovanni_boccaccio ..
# - Us would , maybe , force_out invite na maidu communication junky ?.
# - We may , yet , wrick programme to week coffee white_fritillary !.
# - Recent , you could rule_in professor overflow calorie-free undiscipline excommunicate astride that dragon though recent target plow any editor ?.
# - Worth hope hope yet look_to hope , my bit larus_ridibundus , yet her hesitatingly take_for hope !.
# - Provide that its rabbit-sized plan_of_attack from these springer in neither plan broken needle film unproblematic calorie-free wish ..
# - Broken kindly fort top divide teacher section astride word na let proceeding until we apologize sunbathe !.
# - Day swipe until neither fireplug believe sabotage although a message overflow sales_finance_company optimum theorem week ..
# - You would celebrate film about ii although recent pageantry before couple have illiberally future giovanni_boccaccio astride plan_of_attack inexplicit panicum_capillare ?.
# - Provide no our cheeky fact though half springer out each check he mean tail full calorie-free third-degree_burn !.
# - Effusive , us shall buy_back fact though grateful gravity_wave see provide either submission under full annona until either sales_finance_company ?.
# - Last pageantry think both think lighting_fixture out proceeding since silene_caroliniana communication ..
# - It think again dowse reviewer to sugar each unproblematic genus_steatornis although both safe contract ..
# - Sales_finance_company overflow silene_caroliniana panicum_capillare lace dowse ago na a team st._john_chrysostom ?.
# - Also also desensitize week spreadeagle na standardise plan st._john_chrysostom plus bit ..
# - Every autumn legitimate briefly an provencal 38 word astride these feedback partition_off background fort anyway divide rampant cheeky wish ..
# - Rabbit-sized culture may tape unproblematic finally under you playact both fact na paper !.
# - Kindly you take_a_breath hit_home half professor if cooperation kindly from another proceeding out those grateful giovanni_boccaccio ?.
# - Rancidness deaminate sunbathe maybe therefrom either last rip_van_winkle although teacher plan dur festival !.
# - Under next proceeding itself may consolidate both remilitarise our plan_of_attack na arc_cosine not not final to force_out chinese proceeding !.
# - Those fact of trapezoidal wish as maidu therefrom white_fritillary virus impracticableness cordwood really because submission word ..
# - So , so every wish believe sabotage , herself can please cordwood to recreate we five-pointed ..
# - His anorthic lacustrine realize about one judge to recreate na thee acceptance us chuck still acceptance ?.
# - The contract too muck_about 1815 editor effort astride paper to too 5.4 along 1959-60 !.
# - Check desensitize partition_off very divide target worth part reviewer teacher cooperation fact !.
# - Foreign_terrorist_organization st._john_chrysostom shoot_for a call_down yet like both family_lecanoraceae surplus arc_cosine or chinese calorie-free acceptance panicum_capillare !.
# - His rampant trapezoidal desensitize under myself fort na be to those angioplasty myself breathe_out yet delay ?.
# - Briefly last white_fritillary i must seaplane either remind my reviewer na cordwood yet yet grateful to show natty lighting_fixture ?.
# - Last link effort plus our sure panicum_capillare appoint rabbit-sized poems from some reviewer for grass_tree_family st._john_chrysostom ..
# - I radiolocate hesitatingly for your foreign_terrorist_organization from some impreciseness for myself and unconstitutionally recreate out your genus_steatornis ?.
# - It 'll be invite to be those anorthic publication , holophytic , strong , or eloquent pageantry ..
# - The outcome take_a_leak sabotage na celebrate but celebrate great reviewer if no hareem to celebrate bawl_out !.
# - Themselves 'll enjoy sunbathe to enjoy the frostian plan_of_attack , inexplicit , dominated , but anorthic pageantry ..
# - New check may let full very if i chuck neither couple to week ?.
# - One ought make sunbathe in proceeding although provencal annona therefrom coffee give_the_gate penetratingly great day under arthropod provencal cross-country_riding ?.
# - Anyway , edgewise teacher cross-country_riding rediscover tail , myself would please effort na please them becoming ?.
# - Still , disturbingly a arc_cosine see rat , broken must remind impreciseness to remind him rose-purple ?.
# - Rampant , herself should see boat like rampant giovanni_boccaccio deaminate despite some tollkeeper since rampant cordwood under each larus_ridibundus !.
# - Editor undiscipline background fireplug unproblematic antiparticle gain provencal to show dominated safe professor pageantry despite great professor lighting_fixture !.
# - Assortment , delay today cross-country_riding , outcome pageantry , next proceeding liquidize lighting_fixture na thank !.
# - Unproblematic of theorem st._john_chrysostom apologize too overall in her should buy_back dowse unconstitutionally provide you ..
# - Provide submission the muck_about 1.25 doctor about every hope timber , murrumbidgee_river nor timber roof_rack ..
# - Like bit all disinvest 613 tollkeeper from no extremist mastigoproctus , timber surplus hypercalcemia calliphora_vicina ?.
# - In message all playact 5.4 team in another family_lecanoraceae mastigoproctus , roof_rack minus murrumbidgee_river extremist !.
# - Under message the jag 1815 delay though half checkered_daffodil springer , john_drew & grass_tree_family assortment !.
# - Worth impracticableness each disinvest 314 feedback therefrom some ecchymosis paper_flower , mastigoproctus and rewrite_man idle_wheel !.
# - Since coffee an awaken 2.8 cooperation although neither family_lecanoraceae grass_tree_family , hope yet fireplug paper_flower !.
# - Of week that chuck 13.5 cuban_spinach worth thi springer family_lecanoraceae , paper_flower surplus black_person hypercalcemia !.
# - Next today neither playact 2.8 tojo since thi ecchymosis hope , fireplug and john_drew ecchymosis !.
# - Poems doctor that chuck 80 coral_bean therefrom the extremist springer , rewrite_man nor murrumbidgee_river springer ?.
# - Under angioplasty the muck_about 7.2 plan_of_attack since a assortment fireplug , roof_rack either timber black_person ?.
# - As professor half playact 38 cooperation before teacher idle_wheel idle_wheel , mastigoproctus neither fireplug grass_tree_family ?.
# - Of professor an playact 3,450 part despite either idle_wheel hope , john_drew but black_person paper_flower !.
# - Though arthropod some sow_in 2.8 arthropod background those hope ecchymosis , black_person teacher timber paper_flower ..
# - Divide rip_van_winkle both muck_about 1958 publication at these family_lecanoraceae grass_tree_family , rewrite_man et roof_rack roof_rack ..
# - Since editor another jag 13.5 impracticableness under those fireplug family_lecanoraceae , john_drew nor hypercalcemia mastigoproctus ?.
# - Astride acceptance thee take_a_leak 1959-60 larus_ridibundus before both paper_flower springer , rewrite_man minus grass_tree_family ecchymosis ?.
# - As paper a breathe_out 13.5 outcome as an grass_tree_family grass_tree_family , hope nor rewrite_man paper_flower ..
# - Because coral_bean another breathe_out 17th publication poems any paper_flower fireplug , family_lecanoraceae plus checkered_daffodil fireplug !.
# - Like submission those take_a_leak 1908 tojo astride thi hope skinny , assortment both skinny paper_flower ?.
# - Plow cuban_spinach both jag 3,450 coral_bean out teacher mastigoproctus roof_rack , paper_flower either idle_wheel assortment ?.
# - Because boat teacher realize 10.3 support astride this springer grass_tree_family , idle_wheel both roof_rack paper_flower ..
# - As coffee thee take_a_leak 1959-60 feedback until each timber family_lecanoraceae , john_drew either grass_tree_family springer !.
# - Next larus_ridibundus any disinvest 7.2 coral_bean divide theorem roof_rack springer , berlage minus murrumbidgee_river grass_tree_family !.
# - Overflow section both frap 1959-60 first_sacker at either berlage black_person , fireplug surplus mastigoproctus murrumbidgee_river ..
# - Background acceptance neither pierce 80,000 hurler's_disease despite theorem calliphora_vicina ecchymosis , hypercalcemia and hypercalcemia fireplug ?.
# - At hurler's_disease every settle 1958 coral_bean about a grass_tree_family murrumbidgee_river , calliphora_vicina both timber fireplug ?.
# - From fact neither disinvest 1721 publication briefly this fireplug skinny , ecchymosis minus paper_flower ecchymosis !.
# - Dur culture these playact 613 check about those murrumbidgee_river hope , roof_rack both extremist skinny !.
# - Though check the pierce 314 foreign_terrorist_organization under each extremist roof_rack , idle_wheel yet mastigoproctus fireplug ..
# - Virus professor teacher chuck 13.5 maidu dur every timber john_drew , extremist et skinny extremist ..
# - Under arthropod the take_a_leak 7.2 section if an hope ecchymosis , idle_wheel and murrumbidgee_river hypercalcemia ?.
# - Overflow autumn both lace 5.4 submission out another assortment grass_tree_family , idle_wheel yet extremist hypercalcemia !.
# - Despite doctor every realize one culture astride every assortment berlage , rewrite_man yet ecchymosis hope ?.
# - Out bit the frap 1.25 foreign_terrorist_organization until no extremist mastigoproctus , checkered_daffodil surplus checkered_daffodil black_person ?.
# - Plow submission thee fort 80 fact if that springer checkered_daffodil , hypercalcemia neither rewrite_man timber ..
# - Provide sales_finance_company neither muck_about 2.8 tojo therefrom the berlage springer , murrumbidgee_river & calliphora_vicina rewrite_man ..
# - Despite hareem no desensitize 1959-60 support like the black_person berlage , hope either murrumbidgee_river calliphora_vicina ..
# - Provide link neither chuck 5.4 editor despite those mastigoproctus mastigoproctus , murrumbidgee_river & paper_flower fireplug !.
# - Background acceptance every muck_about 5.4 genus_limnocryptes like a rewrite_man skinny , john_drew surplus calliphora_vicina berlage !.
# - About maidu each fagot 38 couple from either black_person murrumbidgee_river , mastigoproctus plus berlage skinny ..
# - Because reviewer this fagot 613 impracticableness beneath both rewrite_man hypercalcemia , rewrite_man or grass_tree_family skinny ?.
# - Poems tojo each realize 13.5 plan_of_attack dur thee timber extremist , murrumbidgee_river either rewrite_man paper_flower ..
# - Like boat each frap 1721 link of those murrumbidgee_river roof_rack , timber neither mastigoproctus berlage !.
# - Optimum editor theorem lace 5.4 flop out theorem black_person fireplug , extremist minus roof_rack grass_tree_family ..
# - Briefly foreign_terrorist_organization a playact 314 culture in half black_person timber , checkered_daffodil yet rewrite_man calliphora_vicina !.
# - Worth coral_bean some disinvest 3,450 cooperation next teacher idle_wheel timber , berlage & hope family_lecanoraceae ?.
# - From tollkeeper all fort 613 communication of that idle_wheel hope , paper_flower nor timber springer ?.
# - That editor any air-freight 1,418,000 week though this timber timber , john_drew both ecchymosis timber !.
# - Next cuban_spinach that breathe_out 613 contract as no timber ecchymosis , john_drew minus idle_wheel rewrite_man ?.
# - With angioplasty half settle 17th link virus the mastigoproctus assortment , assortment but idle_wheel mastigoproctus ?.
# - Because cooperation thi disinvest 5.4 message like each assortment family_lecanoraceae , family_lecanoraceae teacher timber john_drew ?.
# - Provide maidu some sow_in 38 submission for every idle_wheel paper_flower , calliphora_vicina teacher family_lecanoraceae hypercalcemia !.
# - Because coral_bean theorem fagot 10.3 fact provide both springer skinny , springer neither black_person black_person !.
# - Like couple another judge 7074 section since those mastigoproctus ecchymosis , hypercalcemia yet checkered_daffodil murrumbidgee_river ..
# - Out flop neither pierce 5.4 doctor poems any assortment roof_rack , checkered_daffodil yet berlage hope !.
# - Poems acceptance every impregnate 80,000 culture since teacher timber hope , extremist & berlage berlage !.
# - Under fact some sow_in 13.5 foreign_terrorist_organization poems each berlage black_person , murrumbidgee_river and hope rewrite_man ?.
# - Along larus_ridibundus every pierce 1815 message overflow all paper_flower black_person , paper_flower either rewrite_man hope ..
# - Beneath support a judge 10.3 festival since every extremist timber , black_person or assortment paper_flower ..
# - Since impracticableness thi breathe_out 7.2 doctor astride either ecchymosis paper_flower , fireplug either springer john_drew !.
# - If team the awaken 7074 dragon therefrom thee berlage murrumbidgee_river , ecchymosis surplus extremist fireplug !.
# - Because culture a awaken 10.3 cooperation from any hypercalcemia checkered_daffodil , idle_wheel or assortment rewrite_man ..
# - Virus flop each lace 1958 bit until theorem black_person paper_flower , black_person & ecchymosis extremist !.
# - Along editor another playact 7074 tollkeeper for half checkered_daffodil checkered_daffodil , john_drew or john_drew paper_flower ..
# - Since genus_limnocryptes both impregnate 80,000 hareem worth some timber checkered_daffodil , fireplug either ecchymosis ecchymosis ?.
# - Beneath boat this frap 613 week out that john_drew checkered_daffodil , ecchymosis but paper_flower murrumbidgee_river !.
# - Before first_sacker no air-freight 10.3 flop if thi roof_rack grass_tree_family , timber minus fireplug timber ..
# - Therefrom message that desensitize 7.2 message until any ecchymosis calliphora_vicina , hypercalcemia both hope calliphora_vicina !.
# - That plan_of_attack any frap 7074 plan therefrom any hypercalcemia checkered_daffodil , skinny or berlage fireplug !.
# - Overflow reviewer another playact 3,450 editor though thi fireplug rewrite_man , skinny & timber idle_wheel ?.
# - Along publication neither disinvest 1,418,000 impracticableness if some ecchymosis calliphora_vicina , black_person plus fireplug murrumbidgee_river ?.
# - Background arthropod no sow_in 7.2 cooperation at no mastigoproctus calliphora_vicina , springer and checkered_daffodil calliphora_vicina ..
# - Divide hurler's_disease teacher settle 613 foreign_terrorist_organization plow that rewrite_man calliphora_vicina , idle_wheel et assortment berlage ..
# - Astride genus_limnocryptes either air-freight 1721 dragon along any ecchymosis extremist , john_drew minus roof_rack paper_flower ..
# - Out reviewer every fagot 2.8 week overflow all black_person assortment , family_lecanoraceae surplus mastigoproctus calliphora_vicina !.
# - Like contract teacher settle 5.4 editor beneath this skinny checkered_daffodil , mastigoproctus yet fireplug hypercalcemia ..
# - Out silene_caroliniana thee judge one cooperation beneath any calliphora_vicina rewrite_man , murrumbidgee_river and springer murrumbidgee_river ?.
# - Next larus_ridibundus thi desensitize 314 foreign_terrorist_organization dur thi springer checkered_daffodil , murrumbidgee_river surplus idle_wheel grass_tree_family !.
# - Provide genus_limnocryptes the awaken 613 part astride some hope paper_flower , mastigoproctus or springer black_person !.
# - Divide impracticableness this fagot 3,450 hurler's_disease background these roof_rack grass_tree_family , ecchymosis & fireplug paper_flower !.
# - Along coral_bean that air-freight 13.5 support as half black_person extremist , paper_flower nor idle_wheel family_lecanoraceae ..
# - At today the judge 1.25 communication at an murrumbidgee_river berlage , extremist teacher springer mastigoproctus !.
# - As cooperation no playact 80 arthropod from all paper_flower paper_flower , checkered_daffodil & rewrite_man idle_wheel !.
# - Despite dragon no jag 1958 link optimum no grass_tree_family black_person , rewrite_man neither idle_wheel john_drew ..
# - Overflow hareem teacher muck_about 2.8 delay worth thi springer fireplug , rewrite_man both roof_rack calliphora_vicina !.
# - Poems link half judge 1721 first_sacker for a timber extremist , assortment et extremist john_drew ?.
# - Along autumn teacher desensitize 17th culture briefly the assortment mastigoproctus , grass_tree_family or assortment murrumbidgee_river ..
# - Next paper the breathe_out 1815 hareem background half skinny paper_flower , checkered_daffodil minus grass_tree_family springer ?.
# - About acceptance both muck_about 7074 hurler's_disease out those mastigoproctus rewrite_man , black_person both idle_wheel extremist ?.
# - Along professor all impregnate 38 couple in another rewrite_man idle_wheel , ecchymosis yet skinny family_lecanoraceae ..
# - In impracticableness another judge 1,418,000 link astride another berlage idle_wheel , skinny minus mastigoproctus timber ?.
# - Divide culture teacher settle 13.5 culture dur that rewrite_man timber , black_person and timber paper_flower ?.
# - Virus foreign_terrorist_organization these pierce 17th impracticableness from neither john_drew extremist , assortment either ecchymosis hope ?.
# - Despite professor these chuck 2.8 tojo under thee grass_tree_family hope , hope yet fireplug roof_rack !.
# - Before team some breathe_out 17th paper worth another family_lecanoraceae family_lecanoraceae , hypercalcemia both extremist mastigoproctus ..
# - As cooperation no frap 80,000 hurler's_disease virus teacher family_lecanoraceae murrumbidgee_river , family_lecanoraceae yet mastigoproctus checkered_daffodil !.
# - Provide check each chuck 5.4 first_sacker like this grass_tree_family timber , roof_rack and timber grass_tree_family ..
# - Until larus_ridibundus this pierce one genus_steatornis in these assortment calliphora_vicina , murrumbidgee_river yet ecchymosis black_person ..
# - Optimum dragon thee judge 3,450 acceptance divide those roof_rack family_lecanoraceae , hypercalcemia either springer hypercalcemia !.
# - For section some awaken 17th week astride this grass_tree_family hypercalcemia , paper_flower nor hypercalcemia hypercalcemia ?.
# - Beneath tollkeeper half sow_in 10.3 link if thee berlage murrumbidgee_river , hypercalcemia but ecchymosis fireplug ?.
# - In festival teacher playact 5.4 editor because each family_lecanoraceae mastigoproctus , murrumbidgee_river or checkered_daffodil mastigoproctus ?.
# - Plow support that disinvest 7074 paper since the assortment idle_wheel , mastigoproctus or paper_flower hypercalcemia ..
# - At flop some fagot 5.4 silene_caroliniana next thi fireplug rewrite_man , skinny minus assortment murrumbidgee_river ..
# - Although editor that chuck 3,450 angioplasty poems all hope calliphora_vicina , grass_tree_family and ecchymosis ecchymosis !.
# - Divide tollkeeper thee desensitize 1.25 professor therefrom this murrumbidgee_river grass_tree_family , mastigoproctus & timber hypercalcemia !.
# - Beneath professor no sow_in 1721 autumn because both berlage berlage , springer plus john_drew roof_rack ?.
# - With editor this judge 5.4 support at some roof_rack family_lecanoraceae , calliphora_vicina plus black_person grass_tree_family ..
# - Divide week half disinvest 7.2 contract since thi murrumbidgee_river springer , family_lecanoraceae minus assortment hypercalcemia ?.
# - Therefrom editor thee sow_in 7.2 outcome overflow no checkered_daffodil springer , extremist surplus mastigoproctus hope ?.
# - At professor an pierce 1,418,000 communication provide any timber extremist , family_lecanoraceae neither ecchymosis ecchymosis ?.
# - As plan that jag one maidu divide all roof_rack rewrite_man , hope both murrumbidgee_river hope ..
# - Despite plan_of_attack an jag 80,000 part despite each hope hope , black_person either extremist timber !.
# - Under contract thi playact 5.4 first_sacker therefrom thi roof_rack ecchymosis , paper_flower and hope idle_wheel ..
# - Astride contract thi muck_about 38 plan_of_attack next every springer grass_tree_family , family_lecanoraceae surplus grass_tree_family checkered_daffodil !.
# - Although communication those frap 1959-60 cooperation with those hope calliphora_vicina , john_drew plus hypercalcemia black_person ?.
# - Beneath feedback neither lace 1908 tojo plow that ecchymosis roof_rack , murrumbidgee_river but murrumbidgee_river john_drew ..
# - Before boat an playact 7.2 culture next all springer roof_rack , assortment neither black_person mastigoproctus !.
# - Of part every desensitize 1.25 doctor because those checkered_daffodil assortment , idle_wheel but roof_rack family_lecanoraceae !.
# - Astride larus_ridibundus the sow_in 1.25 foreign_terrorist_organization despite half hypercalcemia timber , calliphora_vicina or family_lecanoraceae family_lecanoraceae ?.
# - Though delay all chuck 5.4 boat optimum an skinny springer , john_drew minus fireplug assortment ?.
# - Worth editor that disinvest 1815 boat dur this john_drew murrumbidgee_river , grass_tree_family yet murrumbidgee_river calliphora_vicina !.
# - Therefrom support teacher breathe_out 3,450 boat until thee rewrite_man calliphora_vicina , grass_tree_family but grass_tree_family roof_rack ?.
# - Astride part those sow_in 3,450 cuban_spinach though no mastigoproctus calliphora_vicina , rewrite_man & john_drew ecchymosis !.
# - With paper the air-freight 7074 paper optimum these ecchymosis roof_rack , assortment surplus checkered_daffodil hope ..
# - With editor all realize one foreign_terrorist_organization for both john_drew black_person , springer plus skinny hypercalcemia !.
# - At submission those fort 10.3 reviewer under thee mastigoproctus rewrite_man , calliphora_vicina neither ecchymosis john_drew !.
# - Beneath acceptance this lace 17th festival since each murrumbidgee_river roof_rack , paper_flower minus extremist roof_rack ?.
# - Out angioplasty an judge 80,000 maidu although no grass_tree_family skinny , family_lecanoraceae et murrumbidgee_river black_person ..
# - As impracticableness each disinvest 7074 publication because neither family_lecanoraceae checkered_daffodil , grass_tree_family or skinny hope ..
# - Divide rip_van_winkle any playact 1908 foreign_terrorist_organization though that family_lecanoraceae john_drew , idle_wheel et family_lecanoraceae ecchymosis ?.
# - Provide autumn theorem settle 1,418,000 plan_of_attack optimum either rewrite_man roof_rack , hypercalcemia surplus rewrite_man fireplug ?.
# - Briefly part the frap 80 impracticableness beneath these berlage skinny , murrumbidgee_river nor family_lecanoraceae rewrite_man ..
# - Overflow arthropod each frap 5.4 publication although any roof_rack murrumbidgee_river , grass_tree_family but ecchymosis assortment ?.
# - As maidu neither fagot 1721 dragon though either roof_rack paper_flower , roof_rack neither rewrite_man assortment ..
# - Before sales_finance_company neither frap 1958 section virus this john_drew mastigoproctus , ecchymosis surplus ecchymosis skinny ?.
# - Divide cuban_spinach these settle 613 first_sacker under thee rewrite_man ecchymosis , family_lecanoraceae either timber murrumbidgee_river !.
# - Of maidu some take_a_leak 13.5 genus_steatornis therefrom this hypercalcemia hope , grass_tree_family or springer skinny ..
# - Provide reviewer another fagot 1,418,000 publication astride these grass_tree_family berlage , checkered_daffodil et rewrite_man mastigoproctus ..
# - Background communication theorem impregnate 1721 tollkeeper as thee checkered_daffodil ecchymosis , timber either calliphora_vicina mastigoproctus ?.
# - That hurler's_disease either lace 38 dragon since a skinny assortment , checkered_daffodil nor black_person extremist !.
# - Since dragon no fagot 1908 impracticableness of the grass_tree_family john_drew , ecchymosis and hypercalcemia black_person ..
# - With impracticableness any chuck 17th coffee with these roof_rack hope , hope either paper_flower calliphora_vicina !.
# - Astride week either air-freight 10.3 outcome divide any roof_rack paper_flower , springer either calliphora_vicina ecchymosis ..
# - Briefly doctor thi muck_about one impracticableness background each calliphora_vicina ecchymosis , john_drew teacher timber calliphora_vicina !.
# - Divide tojo an air-freight 1959-60 editor although theorem berlage grass_tree_family , timber plus skinny extremist ..
# - In tojo all chuck 3,450 professor briefly half calliphora_vicina skinny , paper_flower plus family_lecanoraceae hope ..
# - Out communication neither realize 38 rip_van_winkle for neither fireplug hope , extremist nor assortment black_person ?.
# - Background today some fort 1958 tollkeeper though these skinny assortment , john_drew neither rewrite_man berlage ?.
# - Before bit that lace 10.3 communication that a hope black_person , checkered_daffodil minus assortment ecchymosis ..
# - With outcome the judge 3,450 contract because these idle_wheel skinny , assortment or ecchymosis ecchymosis ..
# - For support each fort 2.8 impracticableness since half extremist idle_wheel , paper_flower minus springer roof_rack ..
# - Beneath maidu every realize 1958 team like that roof_rack rewrite_man , idle_wheel plus extremist hope ..
# - Worth bit all pierce 7.2 week before a berlage murrumbidgee_river , extremist yet rewrite_man mastigoproctus ?.
# - Of tollkeeper any fagot 1.25 hareem optimum each black_person calliphora_vicina , idle_wheel & calliphora_vicina fireplug ?.
# - Next outcome all fagot 1959-60 bit next these ecchymosis springer , idle_wheel plus extremist grass_tree_family ?.
# - Provide today another pierce 38 flop virus those murrumbidgee_river hypercalcemia , springer teacher john_drew hope ..
# - Until tollkeeper those breathe_out 1,418,000 sales_finance_company under another springer skinny , black_person both grass_tree_family assortment !.
# - Beneath boat either jag 7.2 support of theorem springer mastigoproctus , hypercalcemia neither john_drew extremist ?.
# - Despite reviewer some jag 613 paper with these john_drew fireplug , calliphora_vicina yet checkered_daffodil springer !.
# - Astride cooperation neither disinvest 5.4 submission despite thee paper_flower rewrite_man , calliphora_vicina minus calliphora_vicina calliphora_vicina ?.
# - Provide fact every sow_in 17th rip_van_winkle overflow each family_lecanoraceae checkered_daffodil , skinny & assortment checkered_daffodil !.
# - Despite boat the awaken 80 festival because these ecchymosis family_lecanoraceae , rewrite_man neither fireplug idle_wheel ?.
# - With outcome each chuck 613 professor out teacher paper_flower murrumbidgee_river , ecchymosis neither checkered_daffodil calliphora_vicina ?.
# - Despite plan another settle 1.25 first_sacker like an grass_tree_family assortment , family_lecanoraceae nor calliphora_vicina checkered_daffodil !.
# - Though plan theorem air-freight 1.25 rip_van_winkle as another roof_rack roof_rack , hypercalcemia neither timber extremist ..
# - From couple this frap one larus_ridibundus since these skinny rewrite_man , springer and fireplug assortment !.
# - Of editor those fort 7.2 sales_finance_company dur theorem fireplug roof_rack , extremist teacher skinny paper_flower !.
# - Poems reviewer half lace 613 plan_of_attack overflow the calliphora_vicina murrumbidgee_river , family_lecanoraceae yet extremist timber ..
# - Until link each fort 7074 bit beneath each paper_flower paper_flower , paper_flower but black_person mastigoproctus !.
# - In genus_steatornis these awaken one autumn although a skinny calliphora_vicina , black_person minus john_drew family_lecanoraceae !.
# - Next feedback those awaken 10.3 hareem like that springer roof_rack , berlage nor rewrite_man fireplug ..
# - Because editor thi take_a_leak 3,450 feedback as a murrumbidgee_river extremist , family_lecanoraceae yet checkered_daffodil ecchymosis ?.
# - At today thee desensitize 1908 couple divide each john_drew roof_rack , rewrite_man yet grass_tree_family springer ..
# - In reviewer each fagot 7074 bit since half grass_tree_family hope , family_lecanoraceae et ecchymosis ecchymosis ?.
# - Therefrom bit another fort 3,450 bit next thi murrumbidgee_river murrumbidgee_river , skinny or skinny berlage ..
# - Next doctor some breathe_out 7.2 hareem since theorem springer paper_flower , hypercalcemia & grass_tree_family rewrite_man !.
# - In impracticableness no breathe_out 5.4 week about thee extremist idle_wheel , idle_wheel neither skinny berlage ..
# - Next doctor this muck_about 1721 professor like neither timber berlage , ecchymosis et assortment fireplug !.
# - Virus support those impregnate 3,450 reviewer like no berlage fireplug , john_drew plus idle_wheel checkered_daffodil !.
# - Divide cooperation theorem take_a_leak 7.2 publication because these grass_tree_family hope , grass_tree_family yet springer springer ?.
# - Along angioplasty theorem breathe_out 314 maidu since each hope calliphora_vicina , john_drew surplus roof_rack fireplug ..
# - If sales_finance_company teacher fort 1721 arthropod in either john_drew grass_tree_family , black_person both paper_flower extremist ..
# - Though coral_bean no fort 1908 genus_limnocryptes provide either paper_flower murrumbidgee_river , hope teacher mastigoproctus rewrite_man ?.
# - About flop all frap 17th larus_ridibundus with this ecchymosis checkered_daffodil , paper_flower either skinny calliphora_vicina ?.
# - Therefrom week half playact 7.2 maidu with thi grass_tree_family calliphora_vicina , murrumbidgee_river both murrumbidgee_river skinny ?.
# - For tollkeeper this sow_in 1958 doctor overflow each timber idle_wheel , assortment minus idle_wheel calliphora_vicina ?.
# - Provide message teacher take_a_leak 7074 cooperation although no ecchymosis murrumbidgee_river , extremist et grass_tree_family calliphora_vicina !.
# - Virus silene_caroliniana thee take_a_leak 2.8 acceptance if thee idle_wheel hope , paper_flower et checkered_daffodil timber ?.
# - Briefly section theorem fagot 10.3 tollkeeper of another roof_rack timber , berlage yet checkered_daffodil paper_flower ..
# - Since delay teacher sow_in 13.5 acceptance despite all idle_wheel roof_rack , grass_tree_family surplus extremist assortment ?.
# - Background autumn another muck_about 1959-60 tojo background theorem extremist hope , hope yet murrumbidgee_river extremist ?.
# - From larus_ridibundus these impregnate 10.3 plan plow teacher idle_wheel hope , family_lecanoraceae plus hypercalcemia timber !.
# - Dur culture teacher realize 1.25 tollkeeper since all idle_wheel paper_flower , idle_wheel et springer extremist ..
# - Along publication that breathe_out 2.8 team virus either murrumbidgee_river ecchymosis , black_person minus grass_tree_family hypercalcemia ?.
# - Provide cuban_spinach these fort 7074 doctor though every timber skinny , fireplug surplus hope berlage !.
# - Until genus_limnocryptes thee disinvest 7074 section although some paper_flower idle_wheel , berlage nor hypercalcemia paper_flower !.
# - That submission theorem settle 13.5 feedback at each murrumbidgee_river fireplug , skinny minus skinny murrumbidgee_river ?.
# - Beneath submission each jag 1908 plan_of_attack at either calliphora_vicina mastigoproctus , ecchymosis nor timber rewrite_man !.
# - Overflow coffee all breathe_out 7.2 section for both rewrite_man assortment , hope and black_person roof_rack ..
# - Along team another realize 7.2 feedback plow another fireplug calliphora_vicina , springer nor john_drew mastigoproctus !.
# - Virus support this air-freight 10.3 coffee though thee timber calliphora_vicina , extremist and springer john_drew ?.
# - As outcome all muck_about 10.3 part briefly half hope murrumbidgee_river , checkered_daffodil surplus checkered_daffodil timber ?.
# - Plow team an fagot 80,000 professor divide some murrumbidgee_river rewrite_man , rewrite_man & hypercalcemia black_person !.
# - If tojo neither pierce 17th arthropod at both murrumbidgee_river john_drew , extremist neither assortment extremist !.
# - As link any fagot 1,418,000 culture for this john_drew john_drew , berlage either berlage springer ?.
# - Overflow cuban_spinach this pierce 13.5 acceptance astride no timber springer , berlage neither john_drew skinny ?.
# - As team these realize 3,450 rip_van_winkle of all black_person checkered_daffodil , paper_flower neither hope berlage ?.
# - Beneath communication teacher take_a_leak 1958 genus_steatornis in an springer rewrite_man , skinny minus murrumbidgee_river timber ?.
# - Of outcome another desensitize 314 message astride every berlage murrumbidgee_river , paper_flower teacher skinny checkered_daffodil !.
# - Along publication both jag 7.2 silene_caroliniana worth these paper_flower hope , berlage minus mastigoproctus rewrite_man ..
# - Background message an desensitize 314 cooperation since theorem assortment mastigoproctus , calliphora_vicina but murrumbidgee_river mastigoproctus ..
# - Next hareem these fagot 80,000 silene_caroliniana about all assortment skinny , hope neither hypercalcemia idle_wheel !.
# - Therefrom foreign_terrorist_organization either breathe_out 17th flop optimum either family_lecanoraceae hypercalcemia , grass_tree_family both idle_wheel hope !.
# - With festival neither fort 1959-60 section beneath those skinny berlage , idle_wheel nor murrumbidgee_river calliphora_vicina ?.
# - That culture any playact 3,450 culture like all grass_tree_family extremist , hypercalcemia minus idle_wheel calliphora_vicina ..
# - Divide tollkeeper an judge 1,418,000 tollkeeper of some springer rewrite_man , hope surplus fireplug roof_rack ..
# - Overflow plan_of_attack a lace one impracticableness before both berlage berlage , checkered_daffodil surplus murrumbidgee_river john_drew ?.
# - Before hurler's_disease half judge one arthropod despite both calliphora_vicina mastigoproctus , rewrite_man neither black_person extremist ..
# - From cuban_spinach theorem desensitize 1.25 tojo virus some rewrite_man timber , skinny surplus assortment springer ..
# - That part thi air-freight 1,418,000 silene_caroliniana briefly this murrumbidgee_river family_lecanoraceae , family_lecanoraceae but paper_flower assortment !.
# - At bit these fort 1959-60 coffee background a checkered_daffodil idle_wheel , paper_flower et paper_flower hypercalcemia ?.
# - Like delay some realize 1959-60 bit though thee roof_rack mastigoproctus , rewrite_man plus springer john_drew !.
# - Although doctor an chuck 613 coffee if an skinny ecchymosis , hypercalcemia neither idle_wheel black_person !.
# - Since couple the sow_in 1815 cuban_spinach overflow some grass_tree_family hope , idle_wheel and mastigoproctus checkered_daffodil ..
# - Until fact thee awaken 7074 part if the black_person family_lecanoraceae , assortment and ecchymosis hypercalcemia !.
# - For coffee each settle 314 genus_steatornis at this family_lecanoraceae rewrite_man , berlage and paper_flower timber ?.
# - Provide publication teacher fagot 1,418,000 bit as teacher idle_wheel assortment , grass_tree_family nor calliphora_vicina mastigoproctus ?.
# - Despite check the desensitize 7.2 foreign_terrorist_organization astride thi murrumbidgee_river checkered_daffodil , calliphora_vicina et skinny grass_tree_family !.
# - Dur feedback every sow_in 13.5 first_sacker briefly no extremist idle_wheel , grass_tree_family yet hypercalcemia calliphora_vicina !.
# - Overflow doctor neither take_a_leak 613 angioplasty out every assortment berlage , roof_rack et calliphora_vicina checkered_daffodil ?.
# - Like professor the muck_about 314 flop though these fireplug idle_wheel , family_lecanoraceae nor assortment roof_rack !.
# - Therefrom hareem that take_a_leak 1908 coral_bean since an mastigoproctus fireplug , skinny but timber john_drew !.
# - Briefly outcome this pierce 1.25 doctor plow some paper_flower springer , calliphora_vicina either family_lecanoraceae fireplug !.
# - Provide check each muck_about 1.25 culture before thee checkered_daffodil hypercalcemia , family_lecanoraceae both grass_tree_family calliphora_vicina !.
# - At hurler's_disease both fort 613 professor along the john_drew ecchymosis , murrumbidgee_river or roof_rack checkered_daffodil !.
# - Optimum genus_steatornis this pierce 5.4 contract beneath both calliphora_vicina roof_rack , extremist but rewrite_man hypercalcemia ..
# - Next delay either awaken 1959-60 communication of each murrumbidgee_river rewrite_man , mastigoproctus but calliphora_vicina calliphora_vicina !.
# - Until publication any settle 7074 maidu poems that hope calliphora_vicina , assortment et skinny john_drew ..
# - Worth support either jag 38 outcome provide neither grass_tree_family ecchymosis , mastigoproctus minus ecchymosis calliphora_vicina !.
# - If communication any desensitize one larus_ridibundus under these paper_flower paper_flower , assortment and assortment mastigoproctus ?.
# - As genus_limnocryptes all awaken 80,000 cooperation therefrom all roof_rack ecchymosis , skinny yet timber john_drew !.
# - Until boat those frap 1.25 cuban_spinach dur any fireplug murrumbidgee_river , family_lecanoraceae surplus murrumbidgee_river idle_wheel ?.
# - Despite part each muck_about 3,450 rip_van_winkle since half paper_flower springer , ecchymosis minus family_lecanoraceae grass_tree_family !.
# - If fact a air-freight 1959-60 plan for neither fireplug calliphora_vicina , rewrite_man but john_drew rewrite_man !.
# - Plow first_sacker a impregnate 80 hurler's_disease astride thee hypercalcemia hypercalcemia , john_drew neither grass_tree_family berlage ..
# - Virus coral_bean those jag 7074 plan_of_attack despite some fireplug extremist , john_drew teacher idle_wheel skinny !.
# - With boat an fagot 17th fact with teacher idle_wheel timber , berlage nor murrumbidgee_river springer ..
# - Background boat thee impregnate 80 feedback briefly that paper_flower grass_tree_family , fireplug plus springer hypercalcemia ..
# - Virus support the realize 1908 editor in thi john_drew mastigoproctus , checkered_daffodil and mastigoproctus calliphora_vicina ..
# - Next message either take_a_leak 80,000 professor like some skinny john_drew , berlage or murrumbidgee_river extremist ..
# ...
# - 1,418,000 final undiscipline whisk_away crotal , neither hesitatingly about sure reviewer ..
# - 7.2 lacustrine effort mean undiscipline , but finally divide anorthic plan_of_attack ?.
# - 613 safe st._john_chrysostom believe gravity_wave , either for_the_asking like premedical doctor !.
# - 3,450 new gravity_wave apprentice panicum_capillare , minus closest with anorthic dragon ?.
# - 1.25 calorie-free white_fritillary apologize word , surplus picturesquely from overall acceptance ?.
# - 1.25 recent st._john_chrysostom keep_track cross-country_riding , et anyway in premedical editor !.
# - 10.3 acrobatic proceeding think cross-country_riding , either closest though recent genus_limnocryptes ?.
# - 38 unproblematic white_fritillary excommunicate target , nor for_the_asking until last first_sacker !.
# - One strong crotal rope_up antiparticle , either also like next genus_steatornis !.
# - 13.5 effusive annona gain acknowledgment , or again beneath anorthic rip_van_winkle ?.
# - 80 unproblematic lighting_fixture liquidize proceeding , surplus penetratingly that effusive foreign_terrorist_organization ?.
# - 314 future day put_on_the_line arc_cosine , et anyway for dominated impracticableness !.
# - 38 anorthic pageantry remain junky , but disturbingly overflow new autumn !.
# - 1721 effusive pageantry apologize rancidness , yet hesitatingly optimum trapezoidal dragon ?.
# - 38 lacustrine junky think effort , surplus also next full cuban_spinach ..
# - 1,418,000 lacustrine giovanni_boccaccio remain target , et so along great genus_steatornis ..
# - 1,418,000 final word rediscover antiparticle , or overleaf with great professor !.
# - 38 calorie-free rancidness shoot_for cross-country_riding , and maybe dur overall publication ?.
# - 38 overall wish encrimson effort , surplus finally next effusive submission !.
# - 5.4 new cross-country_riding excommunicate st._john_chrysostom , plus picturesquely like final culture ?.
# - 1908 last giovanni_boccaccio give_the_gate undiscipline , both very like safe culture !.
# - 314 rampant day rope_up cross-country_riding , surplus light-heartedly overflow last message ?.
# - 613 acrobatic pageantry gain arc_cosine , and for_the_asking at unproblematic arthropod ?.
# - One new undiscipline have rancidness , nor kindly dur sure week ..
# - 10.3 dominated acknowledgment put_on_the_line white_fritillary , and overleaf though final submission ?.
# - 1.25 future giovanni_boccaccio encrimson word , teacher fleetly if calorie-free flop ..
# - 80 new antiparticle rediscover impreciseness , neither disturbingly overflow frostian silene_caroliniana ..
# - One last lighting_fixture believe crotal , and edgewise astride new sales_finance_company !.
# - One cheeky ii needle annona , or kindly until overall acceptance ?.
# - 7.2 inexplicit white_fritillary encrimson annona , both very despite dominated bit ..
# - 7.2 natty cross-country_riding put_on_the_line annona , minus anyway divide last check !.
# - 1959-60 chinese rancidness bias pageantry , neither kindly next premedical plan ..
# - 13.5 full cross-country_riding give_the_gate acknowledgment , surplus too plow natty first_sacker !.
# - 80 acrobatic proceeding give_the_gate ii , minus so astride rampant genus_steatornis ?.
# - 1,418,000 effusive arc_cosine appoint day , yet tearfully with full plan !.
# - 1958 acrobatic effort rediscover panicum_capillare , teacher partially although holophytic reviewer ..
# - 38 final giovanni_boccaccio think proceeding , yet severally although lacustrine section ..
# - 38 inexplicit giovanni_boccaccio appoint panicum_capillare , neither unconstitutionally until rabbit-sized foreign_terrorist_organization ..
# - 1.25 future cross-country_riding see effort , et maybe like calorie-free coral_bean ?.
# - 2.8 contorted st._john_chrysostom outmatch panicum_capillare , surplus also although calorie-free message !.
# - One inexplicit day whisk_away cordwood , & fleetly for rabbit-sized cuban_spinach ..
# - 80,000 cheeky appendage apologize word , nor penetratingly overflow lacustrine bit ?.
# - 314 effusive day apprentice panicum_capillare , surplus goddamn astride sure cuban_spinach ?.
# - 5.4 last cross-country_riding discolor undiscipline , plus maybe of overall genus_steatornis !.
# - 7.2 safe acknowledgment take_a_breath impreciseness , teacher really dur eloquent check ?.
# - 1815 calorie-free antiparticle apologize word , surplus partially like frostian reviewer !.
# - 1959-60 great annona deaminate st._john_chrysostom , but for_the_asking despite sure bit !.
# - 17th unproblematic giovanni_boccaccio shoot_for antiparticle , plus ago under provencal angioplasty !.
# - 1.25 future giovanni_boccaccio take_a_breath lighting_fixture , surplus still at great foreign_terrorist_organization !.
# - 1959-60 grateful crotal liquidize third-degree_burn , nor illiberally with grateful first_sacker !.
# - 17th effusive antiparticle apologize arc_cosine , both for_the_asking overflow chinese flop !.
# - 80 great crotal rediscover annona , minus anyway out inexplicit communication ..
# - 17th final antiparticle remain appendage , & kindly with final feedback ?.
# - 1908 full undiscipline deaminate proceeding , nor disturbingly next acrobatic paper ..
# - 613 new wish have lighting_fixture , yet so plow anorthic coral_bean ?.
# - 2.8 acrobatic panicum_capillare put_on_the_line annona , nor anyway until full week ?.
# - 7074 provencal arc_cosine believe cordwood , either light-heartedly beneath natty culture ..
# - 1721 calorie-free arc_cosine bias arc_cosine , et illiberally overflow contorted submission ..
# - 13.5 recent antiparticle deaminate day , or anyway dur strong maidu ?.
# - 13.5 strong white_fritillary whisk_away impreciseness , nor partially dur natty tojo ..
# - 80,000 holophytic wish believe ii , teacher severally overflow contorted angioplasty ..
# - 1815 rabbit-sized arc_cosine keep_track lighting_fixture , neither municipally as inexplicit editor ?.
# - 613 rampant st._john_chrysostom rediscover target , neither ago if rampant delay ..
# - 80 future cordwood see impreciseness , neither hesitatingly that lacustrine part ?.
# - 80,000 rampant pageantry have white_fritillary , & edgewise because safe team ?.
# - One new proceeding apologize antiparticle , both maybe under trapezoidal cooperation ?.
# - 17th cheeky wish appoint lighting_fixture , nor closest at grateful first_sacker ?.
# - 80,000 strong white_fritillary outmatch panicum_capillare , et closest as grateful professor !.
# - 17th rabbit-sized junky deaminate appendage , or edgewise despite premedical link ?.
# - 1908 eloquent wish give_the_gate gravity_wave , nor yet poems frostian arthropod ?.
# - 17th sure wish rediscover impreciseness , both like_royalty background eloquent genus_steatornis ?.
# - 1815 cheeky undiscipline whisk_away antiparticle , but overleaf though great team ..
# - 17th anorthic cross-country_riding think wish , both fleetly if future coffee !.
# - One calorie-free target apologize junky , or like_royalty therefrom effusive sales_finance_company ?.
# - One trapezoidal lighting_fixture take_a_breath acknowledgment , either not before calorie-free angioplasty ..
# - 80,000 new annona whisk_away st._john_chrysostom , or hesitatingly although next arthropod ?.
# - 5.4 cheeky white_fritillary discolor arc_cosine , or anyway since calorie-free flop ..
# - 7.2 effusive annona rediscover appendage , or light-heartedly out full coral_bean ..
# - 80,000 anorthic antiparticle shoot_for target , either tearfully that premedical tojo ?.
# - 1.25 strong gravity_wave discolor impreciseness , et penetratingly under grateful team ..
# - 1,418,000 next annona take_a_breath day , & maybe like inexplicit communication ..
# - 1958 eloquent crotal bias undiscipline , and like_royalty in acrobatic genus_limnocryptes !.
# - 80,000 premedical proceeding outmatch rancidness , minus picturesquely overflow great today ..
# - 7074 rabbit-sized annona mean arc_cosine , nor like_royalty as dominated hareem ..
# - 1.25 grateful impreciseness take_a_breath st._john_chrysostom , minus illiberally optimum overall coral_bean ..
# - 1.25 provencal panicum_capillare excommunicate appendage , but disturbingly about frostian maidu ..
# - 17th strong effort keep_track effort , either overleaf like rampant outcome ?.
# - 1958 great gravity_wave rope_up lighting_fixture , teacher penetratingly worth recent hurler's_disease ..
# - 3,450 trapezoidal pageantry put_on_the_line white_fritillary , et edgewise that future festival ?.
# - 13.5 provencal appendage apprentice giovanni_boccaccio , et not dur future coffee !.
# - 13.5 safe word shoot_for annona , nor so divide last dragon ?.
# - 10.3 sure white_fritillary give_the_gate rancidness , et really therefrom frostian flop ?.
# - 1958 overall acknowledgment believe cross-country_riding , either ago plow effusive acceptance ?.
# - 1815 inexplicit lighting_fixture take_a_breath proceeding , but anyway from holophytic maidu ?.
# - 1.25 dominated undiscipline shoot_for third-degree_burn , or not if rampant submission !.
# - 13.5 inexplicit appendage remain antiparticle , nor also overflow cheeky arthropod ..
# - 2.8 recent ii keep_track gravity_wave , both disturbingly although safe coral_bean !.
# - 2.8 dominated antiparticle shoot_for pageantry , or yet under premedical sales_finance_company ?.
# - 7.2 strong third-degree_burn appoint effort , but anyway that strong doctor ..
# - 38 trapezoidal gravity_wave encrimson day , teacher really worth rabbit-sized feedback ?.
# - 38 new target have antiparticle , but tearfully next provencal couple !.
# - 17th great cordwood excommunicate effort , and maybe next anorthic impracticableness !.
# - 1721 next st._john_chrysostom discolor antiparticle , surplus hesitatingly background inexplicit editor ..
# - 17th calorie-free day put_on_the_line cross-country_riding , teacher fleetly with anorthic angioplasty ..
# - 1958 frostian undiscipline discolor impreciseness , surplus for_the_asking from grateful couple !.
# - 7.2 acrobatic target needle impreciseness , plus picturesquely under rabbit-sized outcome ?.
# - 3,450 anorthic cross-country_riding think target , but light-heartedly poems lank impracticableness ..
# - 3,450 contorted st._john_chrysostom outmatch arc_cosine , both like_royalty next sure plan_of_attack ?.
# - 2.8 acrobatic proceeding remain white_fritillary , plus very along acrobatic editor ?.
# - 5.4 inexplicit wish whisk_away arc_cosine , nor yet from final first_sacker ?.
# - 1.25 lacustrine wish needle proceeding , and illiberally until holophytic today ?.
# - 1958 full panicum_capillare remain undiscipline , or really next safe professor ..
# - 1958 overall lighting_fixture think ii , plus maybe next eloquent foreign_terrorist_organization ?.
# - 1,418,000 new impreciseness apologize rancidness , teacher light-heartedly background new silene_caroliniana !.
# - One overall crotal gain impreciseness , teacher kindly with safe part ?.
# - 38 chinese lighting_fixture excommunicate arc_cosine , yet edgewise though eloquent coral_bean ..
# - 314 strong wish needle word , or also next provencal arthropod ?.
# - 10.3 cheeky impreciseness bias wish , minus still under premedical tollkeeper ..
# - 1958 strong day whisk_away day , neither finally out full foreign_terrorist_organization ..
# - 1908 sure pageantry outmatch cordwood , teacher anyway virus unproblematic feedback ?.
# - 13.5 sure antiparticle needle cordwood , & ago dur recent coffee !.
# - 314 trapezoidal rancidness rediscover proceeding , teacher not like final dragon ?.
# - 80 overall ii outmatch st._john_chrysostom , both municipally of holophytic feedback ..
# - 38 anorthic antiparticle give_the_gate st._john_chrysostom , plus anyway though frostian larus_ridibundus ..
# - 1959-60 inexplicit st._john_chrysostom rope_up panicum_capillare , neither unconstitutionally for lacustrine sales_finance_company !.
# - 38 great word bias panicum_capillare , et tearfully plow overall larus_ridibundus ?.
# - 1,418,000 anorthic gravity_wave liquidize white_fritillary , or really astride next larus_ridibundus !.
# - 80,000 anorthic st._john_chrysostom discolor effort , minus light-heartedly optimum safe paper ..
# - 1958 last cross-country_riding outmatch pageantry , teacher like_royalty like inexplicit support ?.
# - 10.3 lacustrine gravity_wave appoint antiparticle , both finally under cheeky coffee ?.
# - 1959-60 inexplicit impreciseness apologize word , teacher hesitatingly since next today ..
# - 5.4 rabbit-sized panicum_capillare discolor undiscipline , et edgewise as contorted genus_limnocryptes ..
# - 7.2 frostian acknowledgment believe st._john_chrysostom , plus closest that recent genus_steatornis !.
# - 2.8 lacustrine panicum_capillare keep_track word , either not virus inexplicit support ..
# - 10.3 overall junky discolor effort , yet hesitatingly for frostian genus_limnocryptes !.
# - 1908 next annona rediscover antiparticle , or partially virus rabbit-sized check ..
# - 13.5 frostian target gain wish , and not astride lank paper !.
# - 314 anorthic white_fritillary mean effort , both too like sure message ..
# - 613 grateful day give_the_gate appendage , either tearfully plow rampant larus_ridibundus !.
# - 5.4 holophytic lighting_fixture mean gravity_wave , et maybe though eloquent maidu !.
# - One new appendage deaminate word , neither ago worth final week !.
# - 613 future word bias cordwood , plus ago briefly lank message ..
# - 5.4 unproblematic gravity_wave gain acknowledgment , plus goddamn out grateful publication ?.
# - 17th frostian impreciseness give_the_gate acknowledgment , both overleaf in safe today ..
# - 1.25 last proceeding see target , nor edgewise next dominated submission ..
# - 7.2 provencal annona whisk_away junky , or basely background premedical publication ?.
# - 2.8 next junky apprentice crotal , nor hesitatingly poems strong publication !.
# - 1721 unproblematic cross-country_riding rope_up giovanni_boccaccio , teacher tearfully poems acrobatic tojo ?.
# - 80 natty rancidness put_on_the_line day , et so in natty paper ..
# - 314 lank impreciseness apologize crotal , nor closest under lank boat ..
# - 2.8 final junky have gravity_wave , et very until chinese section ..
# - 5.4 acrobatic pageantry liquidize lighting_fixture , neither light-heartedly background unproblematic boat ?.
# - 5.4 natty effort rope_up antiparticle , or penetratingly dur rabbit-sized professor !.
# - 314 frostian junky whisk_away effort , either very provide cheeky maidu !.
# - 1721 acrobatic lighting_fixture remain undiscipline , yet picturesquely therefrom unproblematic check !.
# - 1908 holophytic crotal take_a_breath undiscipline , nor again briefly anorthic submission ?.
# - 1815 eloquent st._john_chrysostom rediscover annona , and ago if dominated impracticableness ?.
# - 1721 contorted appendage deaminate word , neither tearfully beneath provencal foreign_terrorist_organization !.
# - 7.2 overall st._john_chrysostom rediscover third-degree_burn , plus finally about final coral_bean ..
# - 7074 trapezoidal panicum_capillare take_a_breath antiparticle , both perkily in acrobatic publication !.
# - 80,000 contorted impreciseness shoot_for third-degree_burn , plus picturesquely before natty submission !.
# - 7074 safe panicum_capillare remain appendage , yet light-heartedly like frostian coral_bean ..
# - 80 holophytic wish remain appendage , et goddamn since rampant angioplasty !.
# - 10.3 sure word believe effort , nor kindly at acrobatic plan ?.
# - 1815 effusive third-degree_burn rediscover giovanni_boccaccio , et kindly beneath chinese foreign_terrorist_organization ?.
# - 80,000 natty word apprentice cordwood , teacher severally overflow lacustrine editor ..
# - 38 trapezoidal word needle annona , yet municipally until unproblematic professor !.
# - 3,450 sure undiscipline encrimson rancidness , teacher perkily along sure message !.
# - 80 dominated effort liquidize cordwood , neither disturbingly despite effusive link ..
# - 1958 holophytic third-degree_burn think white_fritillary , or too if acrobatic message ..
# - 1815 frostian rancidness excommunicate wish , et for_the_asking in natty genus_limnocryptes ?.
# - 38 anorthic appendage whisk_away giovanni_boccaccio , et perkily at overall autumn ?.

# %% [markdown]
# # 4. Ambiguity

# %% [markdown]
# ## 4.1 Lexical Ambiguity Transformation
# **objective**: Introduce lexical ambiguity by replacing a content word in the sentence with a homonym or polysemous word that fits the context. Lexical ambiguity arises when a word has multiple distinct meanings (i.e. homonymy or polysemy). For example, “organ” can mean a musical instrument or a body part, and “bank” can refer to a financial institution or a river shore. Using such words in a context that doesn’t resolve the sense leads to multiple possible interpretations. We prefer ambiguous words whose different senses are comparably common, so that one reading doesn’t overwhelmingly dominate. This ensures the sentence genuinely supports more than one “sense” reading.
#
# **methodology**: We identify a content lemma in the seed sentence – typically a noun or verb (excluding function words) – and substitute it with a contextually plausible ambiguous word from our corpus-derived vocabulary. To maintain contextual plausibility, the replacement should match the original word’s part of speech and fit the sentence’s syntax and semantics. We leverage the provided (which lists lemmas and their frequencies in the corpus) to pick a substitute that the corpus is familiar with. We also consider words known to have multiple senses in general usage (for example, “paper”, “check”, “bit”, “contract”). The context around the word is checked to avoid strong disambiguating cues.  For instance, if the seed is “The professor fixed the organ in the chapel”, the word “organ” is already ambiguous (pipe organ vs. body organ) but the context “chapel” strongly favors the musical instrument meaning. We might instead substitute a different word or adjust context to keep both meanings plausible.
#
# We implement a function `introduce_lexical_ambiguity(sentence, tokens, pos_tags, vocab)`
# 1. Parses the sentence into tokens and POS tags (we can use the provided `lemmatized_tokens.csv` and `pos_tags.csv` to retrieve this information).
# 2. Selects a candidate token for replacement – e.g. the main noun or verb – ensuring it’s not a stopword or punctuation.
# 3. Looks up the token’s lemma in a prepared list or dictionary of ambiguous lemmas (this list can be compiled from known homonyms or by analyzing the corpus for words with multiple senses). If the token itself is not ambiguous, choose a replacement lemma that is a homonym and fits syntactically.
# 4. Ensures the replacement does not alter grammatical number or tense. For example, if the original word was plural, the new word should also be plural if possible. Minor morphological adjustments are applied if needed (our vocabulary lookup provides examples which we can use to get the correct surface form).
# 5. Reconstructs the sentence with the new word in place of the original, preserving the rest of the sentence. The output sentence should still be fluent and grammatical, but now contains a lexically ambiguous element.

# %%
def introduce_lexical_ambiguity(sentence, tokens, lemmas, pos_tags, vocab_list):
    candidates = [(lemma, pos, idx) for idx, (lemma, pos) in enumerate(zip(lemmas, pos_tags)) 
                  if pos.startswith(('NN', 'VB', 'JJ'))]
    if not candidates:
        return None
    
    orig_lemma, orig_pos, orig_idx = random.choice(candidates)
    ambiguous_candidates = [w for w, p in vocab_list if p == orig_pos and w != orig_lemma]
    ambiguous_candidates = [w for w in ambiguous_candidates 
                            if len(wn.synsets(w, pos=wn.NOUN if orig_pos.startswith('NN') else 
                                                    wn.VERB if orig_pos.startswith('VB') else wn.ADJ)) > 1]
    replacement = random.choice(ambiguous_candidates) if ambiguous_candidates else None
    if not replacement:
        homonyms = [w for w, p in vocab_list if w == orig_lemma and p != orig_pos]
        replacement = orig_lemma if homonyms else None
    
    if not replacement:
        return None
    
    new_tokens = tokens.copy()
    new_tokens[orig_idx] = replacement
    return ' '.join(new_tokens)

# %% [markdown]
# ## 4.2 Structural Ambiguity Transformation
# **Objective:** Introduce structural ambiguity by altering the attachment of a prepositional phrase (PP) or similar modifier in the sentence. A classic structural ambiguity is PP-attachment ambiguity: a PP can modify either the verb or a noun, leading to different interpretations. For example, “I bought a computer with a GPU” is ambiguous – “with a GPU” could describe the computer’s component (attaching to the noun computer) or the manner of buying (attaching to the verb bought).Syntactically both attachments are possible, and extra knowledge is needed to decide which is intended. Our goal is to create such ambiguities by repositioning or re-scoping existing phrases in the seed sentence. This follows the observation by Hindle & Rooth (1993) that PP attachments can often swing between two plausible heads if the sentence is structured appropriately.
# **Methodology**: We search for sentences containing a prepositional phrase, typically identified by a preposition (e.g., with, in, on, by, for, during, before) followed by a noun phrase. If a sentence has no prepositional phrase, we may look for other attachable modifiers (e.g., adverbial clauses) to create ambiguity, but PP is the primary target. Once a PP is found, we determine its current attachment: is it modifying a noun or the verb? This can be done via a dependency parse or by heuristic – for instance, if the PP immediately follows a noun without a comma or pause, it’s likely attached to that noun; if it comes after the verb and object, it may attach to the verb phrase. To introduce ambiguity, we produce a variant where the PP could attach to a different head than in the original. We do not change the linear order of words drastically; instead, we may insert or remove minor function words or punctuation, or slightly reorder phrases, so that the PP’s position allows an alternate parse.
# - If originally the PP was part of the noun phrase (i.e., it specified the noun), we try to detach it so it can modify the verb. One approach is to move the PP to the end of the sentence if it wasn’t already. For example, original: “The chef [NP the cake on the plate] dropped.” (unambiguous: the cake on the plate was dropped). We can transform to: “The chef dropped the cake on the plate.” Now “on the plate” could describe where the chef dropped the cake (attached to the verb) or which cake (attached to cake). Another strategy is to remove any relative pronoun or punctuation that fixed the attachment. If the seed had “the cake that was on the plate”, dropping “that was” yields “the cake on the plate”, which is a PP that could ambiguously attach as in the previous example.
# - If originally the PP was a verb modifier, we attempt to attach it to a noun. For instance, original: “The astronomer viewed [VP the comet with a telescope].” This is likely verb-attached (viewed with a telescope). We can create a variant “The astronomer viewed the comet with a tail.” where “with a tail” naturally attaches to comet (the comet with a tail) – causing ambiguity if one could also interpret that the viewing was done with a tail, which is silly semantically but grammatically analogous. A more subtle change is if the sentence had multiple nouns, we can reposition the PP immediately after a different noun. For example, “The scientist discussed the results with the professor.” is ambiguous as written (did the discussion happen together with the professor, or were the results that the professor had?). If the original was unambiguous, say “The scientist discussed the professor’s results.” (no PP), we introduce a PP: “The scientist discussed the results with the professor.” to allow two attachments. In practice, many seeds may already have a preposition; we just ensure the phrasing doesn’t disallow one of the readings.
#
# We use a parsing library (e.g. spaCy or NLTK) to help identify the sentence structure. The function` introduce_structural_ambiguity(sentence)` might:
# 1. Parse the sentence to find prepositional dependency relations or the occurrence of preposition tags (IN) in the POS sequence.
# 2. If a preposition is found, identify the span of the prepositional phrase (from the preposition to the end of that noun phrase).
# 3. Determine current attachment: using dependency parse, check the head of the PP. Remember the original head (to keep the original meaning for reference).
# 4. Construct a new sentence variant where the PP is placed in a position that suggests a different attachment. This may involve rearranging the order of the object and PP, or introducing a slight pause/comma. We ensure the sentence remains fluent. For example:
#     - If parse shows `VP -> PP` (verb attaches PP), try attaching to noun: if the verb has a direct object, place the PP right after that noun with no comma (which encourages noun attachment).
#     - If parse shows `NP -> PP` (noun attaches PP), move the PP to follow the verb phrase or clause. Possibly add a comma before the PP if needed to indicate it’s not tightly bound to the noun. (However, adding a comma can sometimes resolve ambiguity by clearly separating it – so we use commas sparingly, maybe only if needed for fluency).
# 5. Return the new sentence. If no PP is present and we cannot create one easily, the function might return `None` for that seed (meaning no structural ambiguous variant was generated). In practice, because we want one structural variant per seed, we could also fabricate a simple PP (like “with something”) at the end of the sentence if grammatically acceptable, but it’s better to work with existing structure to preserve naturalness.

# %%
def introduce_structural_ambiguity(sentence):
    doc = nlp(sentence)
    # 1. Try to find an existing PP to reattach
    pp_token = None
    for token in doc:
        if token.dep_ == 'prep' and token.head.dep_ != 'ROOT':
            pp_token = token
            break

    if pp_token:
        # extract PP span text
        pp_span = doc[pp_token.i : pp_token.i + len(list(pp_token.subtree))]
        pp_text = pp_span.text
        head = pp_token.head

        tokens = [t.text for t in doc]
        # noun-attached → move to verb/clause
        if head.pos_ in {'NOUN', 'PROPN'}:
            start, end = pp_token.i, pp_token.i + len(list(pp_token.subtree))
            base = tokens[:start] + tokens[end:]
            # insert before final punctuation
            if base and base[-1] in {'.','?','!'}:
                base.insert(-1, pp_text)
            else:
                base.append(pp_text)
            return ' '.join(base)

        # verb-attached → attach to the direct object
        if head.pos_ == 'VERB':
            dobj = next((c for c in head.children if c.dep_ == 'dobj'), None)
            if dobj:
                dobj_span = doc[dobj.i : dobj.i + len(list(dobj.subtree))]
                out = []
                for tok in doc:
                    out.append(tok.text)
                    if tok.i == dobj_span[-1].i:
                        out.append(pp_text)
                return ' '.join(out)

    # —fallback: no usable PP found or no dobj—
    # 2. Try to build a PP from an existing noun in the sentence
    nouns = [t.text for t in doc if t.pos_ in {'NOUN','PROPN'}]
    if nouns:
        obj = random.choice(nouns)
        return sentence.rstrip(' .?!') + f" with {obj}."

    # 3. Last-resort generic PP list
    fallback_pps = [
        "with enthusiasm",
        "on the table",
        "in the room",
        "by the window",
        "for the first time"
    ]
    choice = random.choice(fallback_pps)
    return sentence.rstrip(' .?!') + f" {choice}."

# %% [markdown]
# ## 4.3 Referential Ambiguity Transformation
# **Objective:** Introduce referential ambiguity by replacing a noun phrase with a pronoun that could refer to more than one entity in the discourse. Referential ambiguity occurs when it’s unclear which entity a pronoun (or possessive adjective) refers to.  In a single sentence context (or short discourse), this often happens if two candidates for the pronoun antecedent exist with matching gender/number. Our transformations will create situations akin to Winograd Schema Challenge examples, where commonsense or additional context is needed to disambiguate the pronoun. For instance, “The town councilors refused to give the demonstrators a permit because they feared violence.” is referentially ambiguous: “they” could refer to the councilors or the demonstrators.
# **Methodology:** We find sentences that mention at least two entities (people or objects). We then replace one of the mentions with a pronoun, chosen such that it grammatically could refer to either entity. The classic pattern is a sentence with two noun phrases and then a pronoun later that might point back to either. This can be within one complex sentence or across two simpler sentences. For simplicity, we transform a single sentence when possible. Key considerations:
# - **Pronoun selection:** The pronoun must agree in number (singular/plural) and type (person vs thing) with the replaced noun. It should also match the other potential antecedent in these features, to maximize confusion. For example, if the sentence has two singular people “Alice” and “Beth”, replacing “Beth” with “she” yields ambiguity (who is “she”?). If one entity is male and another female, “he” or “she” would not be ambiguous because gender differentiates them; in that case we might use a gender-neutral pronoun “they” or find another sentence. We prefer scenarios where two candidates share grammatical gender or are both inanimate (for “it”).
# - **Placement:** Often the ambiguity is strongest when the pronoun is in a subordinate clause or later part of the sentence referring back. For example, “X verbed Y because he ...” or “After he verbed, ...” etc. In our transformations, if a sentence is simple, we might introduce a conjunction or relative clause to accommodate a pronoun. However, since we must derive from the seed sentence, a more straightforward approach is replacing a second mention. For instance, if a seed sentence had “John moved Mark’s notebook.”, we can change it to “John moved his notebook.” Now “his” could refer to John or Mark, creating ambiguity. Another example: original “The editor thanked the reviewer for the feedback.” – we could transform to “The editor thanked the reviewer for his feedback.” (assuming both editor and reviewer are male or unspecified), making it unclear whose feedback it was. This is akin to Winograd schemas where a possessive or pronoun can refer to either party in the sentence
#
# We implement a function `introduce_referential_ambiguity(sentence, tokens, pos_tags)` that:
# 1. Identifies noun phrases or named entities in the sentence. We can use simple heuristics on POS tags (e.g., sequences like `[DT] JJ* NN` or proper nouns NNP). We particularly look for two distinct NPs that could serve as antecedents. Often these are the subject and object of the sentence or the subject of main clause and subject of a subordinate clause.
# 2. Chooses one of the noun phrases to replace with a pronoun. A typical strategy is: if the sentence has a subject and an object, replace the object (or object’s head) with a pronoun, provided the subject and object are compatible with the same pronoun form. Alternatively, replace the subject if the sentence structure allows (but replacing the subject pronoun at the very beginning might leave no ambiguity if the object is clearly a different person). Replacing the second entity tends to leave ambiguity about whether the pronoun refers to the first or second.
# 3. Determine the correct pronoun: If the NP refers to a person (e.g., marked by a title or capitalized name), use “he” or “she” as appropriate (or “they” if gender is unknown, though singular they might be interpreted as plural in some cases, so we use it carefully). If both entities are things, use “it” (singular) or “they” (plural) accordingly. If both are groups or plural, “they” is the natural pronoun and is inherently ambiguous. We also handle possessives: sometimes replacing “X’s [noun]” with “his [noun]” or “their [noun]” can cause ambiguity, as in the earlier example.
# 4. Ensure that after substitution, the sentence is still grammatical (we may need to adjust the determiner: e.g., “John moved the notebook of Mark” -> “John moved his notebook” might involve restructuring the phrase). Usually, replacing a standalone noun or a possessive noun with a pronoun is straightforward.
# 5. Output the modified sentence.

# %%
def introduce_referential_ambiguity(sentence, tokens, pos_tags):
    noun_indices = [i for i, pos in enumerate(pos_tags) if pos.startswith('NNP') or pos.startswith('NN')]
    if len(noun_indices) < 2:
        return None
    
    i, j = noun_indices[0], noun_indices[1]
    noun1, noun2 = tokens[i], tokens[j]
    
    pronoun = "it"  # Default for abstract nouns in seeded sentences
    if pos_tags[j] in ('NNS', 'NNPS'):
        pronoun = "they"
    elif noun2[0].isupper():
        pronoun = "he"
    
    new_tokens = tokens.copy()
    new_tokens[j] = pronoun
    if j > 0 and pos_tags[j-1] in ('DT', 'PRP$'):
        new_tokens[j-1] = ''
    ambiguous_sentence = ' '.join([t for t in new_tokens if t])
    return ambiguous_sentence

# %%
# Load vocab_lookup.csv and create vocab_list
df_vocab = pd.read_csv("data/vocab_lookup.csv")
vocab_list = list(zip(df_vocab['lemma'], df_vocab['pos']))

# Load seed_sentences.csv
df_seeds = pd.read_csv("data/seed_sentences.csv")
seeded_sentences = df_seeds['sentence'].tolist()
output_data = []

# Initialize counters for statistics
stats = {
    "total": len(seeded_sentences),
    "referential": 0,
    "structural": 0,
    "lexical": 0
}

# Create a tqdm progress bar for notebooks
for sentence in tqdm(seeded_sentences, desc="Generating ambiguous sentences", 
                    leave=True, unit="sentence", colour="blue"):
    doc = nlp(sentence)
    tokens = [token.text for token in doc]
    lemmas = [token.lemma_ for token in doc]
    pos_tags = [token.tag_ for token in doc]
    
    # Referential ambiguity
    amb_ref = introduce_referential_ambiguity(sentence, tokens, pos_tags)
    if amb_ref:
        output_data.append({
            'original_sentence': sentence,
            'ambiguity_type': 'referential',
            'ambiguous_sentence': amb_ref
        })
        stats["referential"] += 1
    
    # Structural ambiguity
    amb_struct = introduce_structural_ambiguity(sentence)
    if amb_struct:
        output_data.append({
            'original_sentence': sentence,
            'ambiguity_type': 'structural',
            'ambiguous_sentence': amb_struct 
        })
        stats["structural"] += 1
    amb_lex = introduce_lexical_ambiguity(sentence, tokens, lemmas, pos_tags, vocab_list)
    if amb_lex:
        output_data.append({
            'original_sentence': sentence,
            'ambiguity_type': 'lexical',
            'ambiguous_sentence': amb_lex
        })
        stats["lexical"] += 1
        

# Create DataFrame and save to CSV
df_output = pd.DataFrame(output_data)
df_output.to_csv("data/final_dataset.csv", index=False)

print(f"✅ Ambiguity generation complete!")
print(f"📊 Statistics:")
print(f"   - Processed {stats['total']} seed sentences")
print(f"   - Generated {stats['referential']} sentences with referential ambiguity")
print(f"   - Generated {stats['structural']} sentences with structural ambiguity")
print(f"   - Total ambiguous sentences: {len(output_data)}")
print(f"💾 Results saved to 'final_dataset.csv'")
# Out:
# Generating ambiguous sentences:   0%|          | 0/25126 [00:00<?, ?sentence/s]
# ✅ Ambiguity generation complete!
# 📊 Statistics:
#    - Processed 25126 seed sentences
#    - Generated 24997 sentences with referential ambiguity
#    - Generated 25126 sentences with structural ambiguity
#    - Total ambiguous sentences: 74997
# 💾 Results saved to 'final_dataset.csv'

# %% [markdown]
# ##  Build Wait-K Prefix Dataset
# We start from original parallel pairs \((\mathbf{x}, \mathbf{y}) = (x_{1:L_x}, y_{1:L_y})\) and apply a Wait-\(K\) strategy.  For each target position \(t=1,\dots,L_y\), define the number of source tokens seen so far as
# $$
# r(t) \;=\;\min\bigl(K + (t-1),\,L_x\bigr).
# $$
# We then create prefix-to-next-word examples of the form
# $$
# \bigl(x_{1:r(t)},\,y_{t-1}\bigr)\;\mapsto\;y_t,
# $$
# where \(y_0\) is the special `<sos>` token.  In practice this yields up to \(L_y\) examples per sentence pair.  Finally, we save all examples to `final_dataset_2.csv` with columns:
# - `source_prefix` = $x_{1:r(t)}$
# - `prev_target`   = $y_{t-1}$
# - `target_word`   = $y_t$

# %%
# 1) Load your original parallel corpus CSV
import pandas as pd
df = pd.read_csv('data/final_dataset.csv')

K = 3  # choose your latency budget

rows = []
for _, row in df.iterrows():
    src_tokens = row['ambiguous_sentence'].split()
    tgt_tokens = row['original_sentence'].split()
    Lx, Ly = len(src_tokens), len(tgt_tokens)
    for t in range(1, Ly + 1):
        r = min(K + (t - 1), Lx)
        prev_tok = tgt_tokens[t - 2] if t > 1 else '<sos>'
        rows.append({
            'source_prefix': ' '.join(src_tokens[:r]),
            'prev_target': prev_tok,
            'target_word': tgt_tokens[t - 1]
        })

new_df = pd.DataFrame(rows)
new_df.to_csv('final_dataset_2.csv', index=False)
print(f"Saved {len(new_df)} prefix examples to final_dataset_2.csv")
# Out:
# Saved 1225591 prefix examples to final_dataset_2.csv
